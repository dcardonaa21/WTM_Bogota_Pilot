# %% [markdown]
# MÉTRICA:
# *   Cobertura de los programas académicos de tecnología en Medellín.
#
# DATOS:
#
# *   Número de estudiantes y número de graduados por programa académico
# *   Año
# *   Cobertura

# %%
# !git clone "http://github.com/dcardonaa21/WTM_Medellin_Pilot.git"
# Out:
# fatal: destination path 'WTM_Medellin_Pilot' already exists and is not an empty directory.

# %%
import sys 
sys.path.insert(0, "/content/WTM_Medellin_Pilot/STEM_Studio")
sys.path.insert(1, "/content/WTM_Medellin_Pilot/Piloto_Medellin")
import stem_library as sl
import libreria_piloto_medellin as lpm
import pandas as pd
import pathlib

# %%
def calligraphy_unification(names_ls):
    """
    Replaces every spanish accentuated vowel by a simple vowel, takes "*" out from the string and turns the strings into uppercase strings.
    Parameters:
    names_ls: List of strings.
    Returns:
    names_dict: A dictionary with the original strings as keys and uppercase clean strings as values.
    """
    invalid_vowels_dict = {"á":"a", "é":"e", "í":"i", "ó":"o", "ú":"u", "ü":"u", "Á":"A", "É":"E", "Í":"I", "Ó":"O", "Ú":"U", "Ü":"U", "*":"", ",":"", "-":""}
    characters_ls = []
    new_characters_ls = []
    names_dict = dict()
    new_name = str()
    for name in names_ls:
        characters_ls = list(name)
        for character in characters_ls:
            if character in invalid_vowels_dict.keys():
                new_char = invalid_vowels_dict[character]
                new_characters_ls.append(new_char)
            else:
                new_characters_ls.append(character)
        new_name = ("".join(new_characters_ls)).upper()
        names_dict[name] = new_name
        new_name = str()
        new_characters_ls= []
        characters_ls = []
    return names_dict

# %%
graduados_2019_dict = pd.read_excel("https://storage.googleapis.com/piloto_medellin/excel/GRADUADOS-2019.xlsx", sheet_name=None)

# %%
graduados_2019_dict.keys()
# Out:
# dict_keys(['GRADUADOS 2019'])

# %%
graduados_2019_df = graduados_2019_dict['GRADUADOS 2019']
graduados_2019_df.head(10)
# Out:
#                                           Unnamed: 0  ... Unnamed: 38
# 0    GRADUADOS EN EDUCACIÓN SUPERIOR - COLOMBIA 2019  ...         NaN
# 1   Fecha de corte de la información: Agosto de 2020  ...         NaN
# 2  Fuente: Minsiterio de Educación Nacional - Obs...  ...         NaN
# 3  La información suministrada corresponde a lo r...  ...         NaN
# 4  Notas: \nA partir de la información de la vige...  ...         NaN
# 5                           CÓDIGO DE LA INSTITUCIÓN  ...   GRADUADOS
# 6                                               1701  ...           1
# 7                                               1701  ...           1
# 8                                               1701  ...           5
# 9                                               1701  ...           3
#
# [10 rows x 39 columns]

# %%
graduados_2019_df["Unnamed: 11"].value_counts()
# Out:
# BOGOTÁ, D.C.                        21955
# MEDELLÍN                             4613
# CALI                                 2052
# BARRANQUILLA                         1820
# BUCARAMANGA                          1661
#                                     ...
# MARINILLA                               5
# COVEÑAS                                 4
# PUERTO BERRÍO                           3
# LETICIA                                 3
# MUNICIPIO DE DOMICILIO DE LA IES        1
# Name: Unnamed: 11, Length: 72, dtype: int64

# %% [markdown]
# Definir diccionario con los nombres de las columnas que se quieren cambiar:

# %%
rename_columns_dict = {
 "Unnamed: 2": 'INSTITUCION DE EDUCACION SUPERIOR (IES)',
 "Unnamed: 17": 'NIVEL DE FORMACION',
 "Unnamed: 23": 'NUCLEO BASICO DEL CONOCIMIENTO (NBC)',
 "Unnamed: 38": "GRADUADOS" 
}

# %% [markdown]
# Limpiar filas vacías:

# %%
graduados_2019_df.drop(graduados_2019_df.index[0:6], inplace=True)

# %% [markdown]
# Verificar:

# %%
graduados_2019_df.head()
# Out:
#    Unnamed: 0 Unnamed: 1  ... Unnamed: 37 Unnamed: 38
# 6        1701       1701  ...           1           1
# 7        1701       1701  ...           1           1
# 8        1701       1701  ...           1           5
# 9        1701       1701  ...           1           3
# 10       1701       1701  ...           1           2
#
# [5 rows x 39 columns]

# %%
graduados_2019_df = graduados_2019_df.loc[graduados_2019_df["Unnamed: 11"] == "MEDELLÍN", :]

# %%
filtered1_df = graduados_2019_df.filter(["Unnamed: 2", "Unnamed: 17", "Unnamed: 23", "Unnamed: 38"])

# %% [markdown]
# Verificar:

# %%
filtered1_df
# Out:
#                                          Unnamed: 2  ... Unnamed: 38
# 533    INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...           3
# 534    INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...           2
# 535    INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...          15
# 536    INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...           6
# 537    INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...          22
# ...                                             ...  ...         ...
# 42234        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...           5
# 42235        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...           1
# 42236        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...           1
# 42237        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...          52
# 42238        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...          44
#
# [4613 rows x 4 columns]

# %% [markdown]
# Renombrar las columnas del dataframe filtrado:

# %%
filtered1_df.rename(columns=rename_columns_dict, inplace=True )

# %% [markdown]
# Verificar:

# %%
filtered1_df.head()
# Out:
#           INSTITUCION DE EDUCACION SUPERIOR (IES)  ... GRADUADOS
# 533  INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...         3
# 534  INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...         2
# 535  INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...        15
# 536  INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...         6
# 537  INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...        22
#
# [5 rows x 4 columns]

# %% [markdown]
# Cambiar índices:

# %%
filtered1_df.index = list(range(0, len(filtered1_df.iloc[:, 0])))
filtered1_df
# Out:
#            INSTITUCION DE EDUCACION SUPERIOR (IES)  ... GRADUADOS
# 0     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...         3
# 1     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...         2
# 2     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...        15
# 3     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...         6
# 4     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...        22
# ...                                            ...  ...       ...
# 4608        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...         5
# 4609        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...         1
# 4610        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...         1
# 4611        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...        52
# 4612        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...        44
#
# [4613 rows x 4 columns]

# %%
filtered1_df["AÑO"] = [2019] * len(filtered1_df.iloc[:, 0])
filtered1_df
# Out:
#            INSTITUCION DE EDUCACION SUPERIOR (IES)  ...   AÑO
# 0     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...  2019
# 1     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...  2019
# 2     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...  2019
# 3     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...  2019
# 4     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...  2019
# ...                                            ...  ...   ...
# 4608        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...  2019
# 4609        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...  2019
# 4610        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...  2019
# 4611        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...  2019
# 4612        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...  2019
#
# [4613 rows x 5 columns]

# %%
graduados_df = filtered1_df.filter(["INSTITUCION DE EDUCACION SUPERIOR (IES)", 
                                       "NIVEL DE FORMACION", 
                                       "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", 
                                       "AÑO", 
                                       "GRADUADOS"])

# %%
graduados_df
# Out:
#            INSTITUCION DE EDUCACION SUPERIOR (IES)  ... GRADUADOS
# 0     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...         3
# 1     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...         2
# 2     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...        15
# 3     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...         6
# 4     INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...        22
# ...                                            ...  ...       ...
# 4608        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...         5
# 4609        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...         1
# 4610        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...         1
# 4611        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...        52
# 4612        UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM  ...        44
#
# [4613 rows x 5 columns]

# %%
graduados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].value_counts()
# Out:
# ADMINISTRACIÓN                                           1033
# CONTADURÍA PÚBLICA                                        431
# DERECHO Y AFINES                                          334
# INGENIERÍA DE SISTEMAS, TELEMÁTICA Y AFINES               302
# EDUCACIÓN                                                 299
# MEDICINA                                                  181
# PSICOLOGÍA                                                178
# INGENIERÍA INDUSTRIAL Y AFINES                            142
# INGENIERÍA CIVIL Y AFINES                                  98
# COMUNICACIÓN SOCIAL, PERIODISMO Y AFINES                   95
# DISEÑO                                                     87
# SALUD PÚBLICA                                              86
# ECONOMÍA                                                   81
# OTRAS INGENIERÍAS                                          80
# INGENIERÍA AMBIENTAL, SANITARIA Y AFINES                   79
# INGENIERÍA ELECTRÓNICA, TELECOMUNICACIONES Y AFINES        72
# INGENIERÍA MECÁNICA Y AFINES                               67
# ARQUITECTURA                                               63
# SOCIOLOGÍA, TRABAJO SOCIAL Y AFINES                        56
# BIOLOGÍA, MICROBIOLOGÍA Y AFINES                           47
# MATEMÁTICAS, ESTADÍSTICA Y AFINES                          41
# CIENCIA POLÍTICA, RELACIONES INTERNACIONALES               40
# INGENIERÍA ELÉCTRICA Y AFINES                              40
# ODONTOLOGÍA                                                40
# FILOSOFÍA, TEOLOGÍA Y AFINES                               39
# ARTES PLÁSTICAS, VISUALES Y AFINES                         39
# INGENIERÍA ADMINISTRATIVA Y AFINES                         37
# TERAPIAS                                                   34
# AGRONOMÍA                                                  33
# QUÍMICA Y AFINES                                           30
# INGENIERÍA DE MINAS, METALURGIA Y AFINES                   27
# PUBLICIDAD Y AFINES                                        26
# DEPORTES, EDUCACIÓN FÍSICA Y RECREACIÓN                    25
# ENFERMERÍA                                                 25
# MÚSICA                                                     25
# MEDICINA VETERINARIA                                       24
# BIBLIOTECOLOGÍA, OTROS DE CIENCIAS SOCIALES Y HUMANAS      24
# INGENIERÍA QUÍMICA Y AFINES                                24
# INGENIERÍA AGROINDUSTRIAL, ALIMENTOS Y AFINES              23
# FÍSICA                                                     23
# LENGUAS MODERNAS, LITERATURA, LINGUÍSTICA Y AFINES         22
# INGENIERÍA BIOMÉDICA Y AFINES                              20
# GEOGRAFÍA, HISTORIA                                        20
# BACTERIOLOGÍA                                              20
# INGENIERÍA AGRÍCOLA, FORESTAL Y AFINES                     13
# GEOLOGÍA, OTROS PROGRAMAS DE CIENCIAS NATURALES            13
# ARTES REPRESENTATIVAS                                      12
# OTROS PROGRAMAS ASOCIADOS A BELLAS ARTES                   12
# ANTROPOLOGÍA Y  ARTES LIBERALES                            12
# INGENIERÍA AGRONÓMICA, PECUARIA Y AFINES                   12
# ZOOTECNIA                                                  10
# NUTRICIÓN Y DIETÉTICA                                       8
# OPTOMETRÍA, OTROS PROGRAMAS DE CIENCIAS DE LA SALUD         5
# FORMACIÓN RELACIONADA CON EL CAMPO MILITAR O POLICIAL       2
# INSTRUMENTACIÓN QUIRÚRGICA                                  2
# Name: NUCLEO BASICO DEL CONOCIMIENTO (NBC), dtype: int64

# %%
graduados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = graduados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].replace("DISEÑO", "DISENIO")

# %%
graduados_df["NIVEL DE FORMACION"].value_counts()
# Out:
# UNIVERSITARIA                        1947
# ESPECIALIZACIÓN UNIVERSITARIA        1071
# MAESTRÍA                              721
# TECNOLÓGICA                           558
# DOCTORADO                             121
# ESPECIALIZACIÓN MÉDICO QUIRÚRGICA     120
# FORMACIÓN TÉCNICA PROFESIONAL          69
# ESPECIALIZACIÓN TECNOLÓGICA             6
# Name: NIVEL DE FORMACION, dtype: int64

# %%
graduados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"].value_counts()
# Out:
# CORPORACION UNIVERSITARIA REMINGTON                        693
# UNIVERSIDAD DE ANTIOQUIA                                   680
# UNIVERSIDAD PONTIFICIA BOLIVARIANA                         508
# UNIVERSIDAD EAFIT-                                         351
# UNIVERSIDAD DE MEDELLIN                                    310
# UNIVERSIDAD NACIONAL DE COLOMBIA                           299
# UNIVERSIDAD CES                                            201
# UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM                     191
# POLITECNICO COLOMBIANO JAIME ISAZA CADAVID                 179
# INSTITUTO TECNOLOGICO METROPOLITANO                        138
# TECNOLOGICO DE ANTIOQUIA                                   137
# UNIVERSIDAD DE SAN BUENAVENTURA                            122
# UNIVERSIDAD COOPERATIVA DE COLOMBIA                        111
# UNIVERSIDAD AUTONOMA LATINOAMERICANA-UNAULA-                94
# INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA                81
# FUNDACION UNIVERSITARIA ESUMER                              80
# INSTITUCIÓN UNIVERSITARIA PASCUAL BRAVO                     76
# FUNDACION UNIVERSITARIA AUTONOMA DE LAS AMERICAS            73
# FUNDACION ESCUELA COLOMBIANA DE MERCADOTECNIA -ESCOLME-     61
# COLEGIO MAYOR DE ANTIOQUIA                                  56
# FUNDACION UNIVERSITARIA MARIA CANO                          51
# CORPORACION COLEGIATURA COLOMBIANA                          29
# CORPORACION UNIVERSITARIA ADVENTISTA - UNAC                 29
# CORPORACION ACADEMIA SUPERIOR DE ARTES                      22
# CORPORACION UNIVERSITARIA U DE COLOMBIA                     16
# FUNDACION UNIVERSITARIA BELLAS ARTES                        12
# ESCUELA DE TECNOLOGIAS DE ANTIOQUIA -ETA-                    9
# FUNDACION UNIVERSITARIA SEMINARIO BIBLICO DE COLOMBIA        2
# CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA -ATEC-          2
# Name: INSTITUCION DE EDUCACION SUPERIOR (IES), dtype: int64

# %%
graduados_df["GRADUADOS"].isnull().value_counts()
# Out:
# False    4613
# Name: GRADUADOS, dtype: int64

# %%
stem_nbc_ls = [
              "INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES", 
              "INGENIERIA INDUSTRIAL Y AFINES ",
              "ECONOMIA",
              "INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES",
              "INGENIERIA AMBIENTAL, SANITARIA Y AFINES",             
              "INGENIERIA CIVIL Y AFINES",
              "INGENIERIA MECANICA Y AFINES",
              "BIOLOGIA, MICROBIOLOGIA Y AFINES",
              "INGENIERIA ELECTRICA Y AFINES",
              "INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES",
              "QUIMICA Y AFINES",
              "OTRAS INGENIERIAS",
              "MATEMATICAS, ESTADISTICA Y AFINES",
              "INGENIERIA QUIMICA Y AFINES",
              "INGENIERIA AGRONOMICA, PECUARIA Y AFINES",
              "INGENIERIA AGRICOLA, FORESTAL Y AFINES",
              "INGENIERIA DE MINAS, METALURGIA Y AFINES",
              "INGENIERIA ADMINISTRATIVA Y AFINES",
              "BACTERIOLOGIA",
              "GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES",
              "FISICA",
              "INGENIERIA BIOMEDICA Y AFINES",
              "INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES",
              "DISENIO"
]

# %%
nbc_base_dict = calligraphy_unification(stem_nbc_ls)
nbc_dict = calligraphy_unification(graduados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"])
ies_dict = calligraphy_unification(graduados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"])
nf_dict = calligraphy_unification(graduados_df["NIVEL DE FORMACION"])

# %%
graduados1_df = pd.DataFrame()

# %%
for row_num in range(0, len(graduados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"])):
  initial_str = graduados_df.loc[row_num,"INSTITUCION DE EDUCACION SUPERIOR (IES)"]
  if initial_str in ies_dict.keys():
    graduados1_df.loc[row_num, "INSTITUCION DE EDUCACION SUPERIOR (IES)"] = ies_dict[initial_str]

# %%
for row_num in range(0, len(graduados_df["NIVEL DE FORMACION"])):
  initial_str = graduados_df.loc[row_num,"NIVEL DE FORMACION"]
  if initial_str in nf_dict.keys():
    graduados1_df.loc[row_num, "NIVEL DE FORMACION"] = nf_dict[initial_str]

# %%
for row_num in range(0, len(graduados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"])):
  initial_str = graduados_df.loc[row_num,"NUCLEO BASICO DEL CONOCIMIENTO (NBC)"]
  if initial_str in nbc_dict.keys():
    graduados_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = nbc_dict[initial_str]
  if graduados_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] in nbc_base_dict.values():
    graduados1_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = graduados_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] 
  else:
    graduados1_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = "Null"

# %%
graduados1_df["AÑO"] =  graduados_df["AÑO"]
graduados1_df["GRADUADOS"] =  graduados_df["GRADUADOS"]

# %%
graduados1_df = graduados1_df.loc[graduados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] != "Null", :]

# %%
graduados1_df.index = list(range(0, len(graduados1_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"])))

# %%
graduados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].value_counts()
# Out:
# INGENIERIA DE SISTEMAS TELEMATICA Y AFINES            302
# INGENIERIA CIVIL Y AFINES                              98
# DISENIO                                                87
# ECONOMIA                                               81
# OTRAS INGENIERIAS                                      80
# INGENIERIA AMBIENTAL SANITARIA Y AFINES                79
# INGENIERIA ELECTRONICA TELECOMUNICACIONES Y AFINES     72
# INGENIERIA MECANICA Y AFINES                           67
# BIOLOGIA MICROBIOLOGIA Y AFINES                        47
# MATEMATICAS ESTADISTICA Y AFINES                       41
# INGENIERIA ELECTRICA Y AFINES                          40
# INGENIERIA ADMINISTRATIVA Y AFINES                     37
# QUIMICA Y AFINES                                       30
# INGENIERIA DE MINAS METALURGIA Y AFINES                27
# INGENIERIA QUIMICA Y AFINES                            24
# FISICA                                                 23
# INGENIERIA AGROINDUSTRIAL ALIMENTOS Y AFINES           23
# BACTERIOLOGIA                                          20
# INGENIERIA BIOMEDICA Y AFINES                          20
# GEOLOGIA OTROS PROGRAMAS DE CIENCIAS NATURALES         13
# INGENIERIA AGRICOLA FORESTAL Y AFINES                  13
# INGENIERIA AGRONOMICA PECUARIA Y AFINES                12
# Name: NUCLEO BASICO DEL CONOCIMIENTO (NBC), dtype: int64

# %%
sum = 0
resta = 0
for valor in graduados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"]:
  if valor in nbc_base_dict.values():
    sum = sum + 1
  else:
    resta = resta + 1  
print(sum, resta)
# Out:
# 1236 0

# %% [markdown]
# Volver a poner las comas en la columna de NBC:

# %%
nbc_base_dict
# Out:
# {'BACTERIOLOGIA': 'BACTERIOLOGIA',
#  'BIOLOGIA, MICROBIOLOGIA Y AFINES': 'BIOLOGIA MICROBIOLOGIA Y AFINES',
#  'DISENIO': 'DISENIO',
#  'ECONOMIA': 'ECONOMIA',
#  'FISICA': 'FISICA',
#  'GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES': 'GEOLOGIA OTROS PROGRAMAS DE CIENCIAS NATURALES',
#  'INGENIERIA ADMINISTRATIVA Y AFINES': 'INGENIERIA ADMINISTRATIVA Y AFINES',
#  'INGENIERIA AGRICOLA, FORESTAL Y AFINES': 'INGENIERIA AGRICOLA FORESTAL Y AFINES',
#  'INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES': 'INGENIERIA AGROINDUSTRIAL ALIMENTOS Y AFINES',
#  'INGENIERIA AGRONOMICA, PECUARIA Y AFINES': 'INGENIERIA AGRONOMICA PECUARIA Y AFINES',
#  'INGENIERIA AMBIENTAL, SANITARIA Y AFINES': 'INGENIERIA AMBIENTAL SANITARIA Y AFINES',
#  'INGENIERIA BIOMEDICA Y AFINES': 'INGENIERIA BIOMEDICA Y AFINES',
#  'INGENIERIA CIVIL Y AFINES': 'INGENIERIA CIVIL Y AFINES',
#  'INGENIERIA DE MINAS, METALURGIA Y AFINES': 'INGENIERIA DE MINAS METALURGIA Y AFINES',
#  'INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES': 'INGENIERIA DE SISTEMAS TELEMATICA Y AFINES',
#  'INGENIERIA ELECTRICA Y AFINES': 'INGENIERIA ELECTRICA Y AFINES',
#  'INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES': 'INGENIERIA ELECTRONICA TELECOMUNICACIONES Y AFINES',
#  'INGENIERIA INDUSTRIAL Y AFINES ': 'INGENIERIA INDUSTRIAL Y AFINES ',
#  'INGENIERIA MECANICA Y AFINES': 'INGENIERIA MECANICA Y AFINES',
#  'INGENIERIA QUIMICA Y AFINES': 'INGENIERIA QUIMICA Y AFINES',
#  'MATEMATICAS, ESTADISTICA Y AFINES': 'MATEMATICAS ESTADISTICA Y AFINES',
#  'OTRAS INGENIERIAS': 'OTRAS INGENIERIAS',
#  'QUIMICA Y AFINES': 'QUIMICA Y AFINES'}

# %%
coma_dict = dict()
for key, value in nbc_base_dict.items():
  coma_dict[value] = key

coma_dict
# Out:
# {'BACTERIOLOGIA': 'BACTERIOLOGIA',
#  'BIOLOGIA MICROBIOLOGIA Y AFINES': 'BIOLOGIA, MICROBIOLOGIA Y AFINES',
#  'DISENIO': 'DISENIO',
#  'ECONOMIA': 'ECONOMIA',
#  'FISICA': 'FISICA',
#  'GEOLOGIA OTROS PROGRAMAS DE CIENCIAS NATURALES': 'GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES',
#  'INGENIERIA ADMINISTRATIVA Y AFINES': 'INGENIERIA ADMINISTRATIVA Y AFINES',
#  'INGENIERIA AGRICOLA FORESTAL Y AFINES': 'INGENIERIA AGRICOLA, FORESTAL Y AFINES',
#  'INGENIERIA AGROINDUSTRIAL ALIMENTOS Y AFINES': 'INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES',
#  'INGENIERIA AGRONOMICA PECUARIA Y AFINES': 'INGENIERIA AGRONOMICA, PECUARIA Y AFINES',
#  'INGENIERIA AMBIENTAL SANITARIA Y AFINES': 'INGENIERIA AMBIENTAL, SANITARIA Y AFINES',
#  'INGENIERIA BIOMEDICA Y AFINES': 'INGENIERIA BIOMEDICA Y AFINES',
#  'INGENIERIA CIVIL Y AFINES': 'INGENIERIA CIVIL Y AFINES',
#  'INGENIERIA DE MINAS METALURGIA Y AFINES': 'INGENIERIA DE MINAS, METALURGIA Y AFINES',
#  'INGENIERIA DE SISTEMAS TELEMATICA Y AFINES': 'INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES',
#  'INGENIERIA ELECTRICA Y AFINES': 'INGENIERIA ELECTRICA Y AFINES',
#  'INGENIERIA ELECTRONICA TELECOMUNICACIONES Y AFINES': 'INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES',
#  'INGENIERIA INDUSTRIAL Y AFINES ': 'INGENIERIA INDUSTRIAL Y AFINES ',
#  'INGENIERIA MECANICA Y AFINES': 'INGENIERIA MECANICA Y AFINES',
#  'INGENIERIA QUIMICA Y AFINES': 'INGENIERIA QUIMICA Y AFINES',
#  'MATEMATICAS ESTADISTICA Y AFINES': 'MATEMATICAS, ESTADISTICA Y AFINES',
#  'OTRAS INGENIERIAS': 'OTRAS INGENIERIAS',
#  'QUIMICA Y AFINES': 'QUIMICA Y AFINES'}

# %%
for row_num in range(0, len(graduados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"])):
  key = graduados1_df.loc[row_num,"NUCLEO BASICO DEL CONOCIMIENTO (NBC)"]
  if key in coma_dict.keys():
    graduados1_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = coma_dict[key]

# %%
graduados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].value_counts()
# Out:
# INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES            302
# INGENIERIA CIVIL Y AFINES                               98
# DISENIO                                                 87
# ECONOMIA                                                81
# OTRAS INGENIERIAS                                       80
# INGENIERIA AMBIENTAL, SANITARIA Y AFINES                79
# INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES     72
# INGENIERIA MECANICA Y AFINES                            67
# BIOLOGIA, MICROBIOLOGIA Y AFINES                        47
# MATEMATICAS, ESTADISTICA Y AFINES                       41
# INGENIERIA ELECTRICA Y AFINES                           40
# INGENIERIA ADMINISTRATIVA Y AFINES                      37
# QUIMICA Y AFINES                                        30
# INGENIERIA DE MINAS, METALURGIA Y AFINES                27
# INGENIERIA QUIMICA Y AFINES                             24
# FISICA                                                  23
# INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES           23
# BACTERIOLOGIA                                           20
# INGENIERIA BIOMEDICA Y AFINES                           20
# GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES         13
# INGENIERIA AGRICOLA, FORESTAL Y AFINES                  13
# INGENIERIA AGRONOMICA, PECUARIA Y AFINES                12
# Name: NUCLEO BASICO DEL CONOCIMIENTO (NBC), dtype: int64

# %%
graduados1_df
# Out:
#                INSTITUCION DE EDUCACION SUPERIOR (IES)  ... GRADUADOS
# 0         INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...         3
# 1         INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...        15
# 2         INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...         6
# 3           CORPORACION UNIVERSITARIA ADVENTISTA  UNAC  ...         1
# 4                                    UNIVERSIDAD EAFIT  ...        22
# ...                                                ...  ...       ...
# 1231                           UNIVERSIDAD DE MEDELLIN  ...         7
# 1232                           UNIVERSIDAD DE MEDELLIN  ...         1
# 1233                   UNIVERSIDAD DE SAN BUENAVENTURA  ...         6
# 1234                   UNIVERSIDAD DE SAN BUENAVENTURA  ...         3
# 1235  FUNDACION UNIVERSITARIA AUTONOMA DE LAS AMERICAS  ...         4
#
# [1236 rows x 5 columns]

# %%
# !mkdir /content/WTM_Medellin_Pilot/Piloto_Medellin/data/clean
# Out:
# mkdir: cannot create directory ‘/content/WTM_Medellin_Pilot/Piloto_Medellin/data/clean’: File exists

# %%
graduados1_df.to_csv("/content/WTM_Medellin_Pilot/Piloto_Medellin/data/clean/graduados_2019.csv", index=False)
