# %% [markdown]
# MÉTRICA:
# *   Cobertura de los programas académicos de tecnología en Medellín.
#
# DATOS:
#
# *   Número de estudiantes y número de graduados por programa académico
# *   Año
# *   Cobertura

# %%
# !git clone "http://github.com/dcardonaa21/WTM_Medellin_Pilot.git"
# Out:
# fatal: destination path 'WTM_Medellin_Pilot' already exists and is not an empty directory.

# %%
import sys 
sys.path.insert(0, "/content/WTM_Medellin_Pilot/STEM_Studio")
sys.path.insert(1, "/content/WTM_Medellin_Pilot/Piloto_Medellin")
import stem_library as sl
import libreria_piloto_medellin as lpm
import pandas as pd
import pathlib
import numpy as np

# %%
def calligraphy_unification(names_ls):
    """
    Replaces every spanish accentuated vowel by a simple vowel, takes "*" out from the string and turns the strings into uppercase strings.
    Parameters:
    names_ls: List of strings.
    Returns:
    names_dict: A dictionary with the original strings as keys and uppercase clean strings as values.
    """
    invalid_vowels_dict = {"á":"a", "é":"e", "í":"i", "ó":"o", "ú":"u", "ü":"u", "Á":"A", "É":"E", "Í":"I", "Ó":"O", "Ú":"U", "Ü":"U", "*":"", ",":"", "-":""}
    characters_ls = []
    new_characters_ls = []
    names_dict = dict()
    new_name = str()
    for name in names_ls:
        characters_ls = list(name)
        for character in characters_ls:
            if character in invalid_vowels_dict.keys():
                new_char = invalid_vowels_dict[character]
                new_characters_ls.append(new_char)
            else:
                new_characters_ls.append(character)
        new_name = ("".join(new_characters_ls)).upper()
        names_dict[name] = new_name
        new_name = str()
        new_characters_ls= []
        characters_ls = []
    return names_dict

# %%
matriculados_2016_dict = pd.read_excel("https://storage.googleapis.com/piloto_medellin/excel/MATRICULADOS-2016.xlsx", sheet_name=None)

# %% [markdown]
# Ver pestañas del archivo de excel:

# %%
matriculados_2016_dict.keys()
# Out:
# dict_keys(['Matriculados_2016'])

# %% [markdown]
# Definir dataframe que contenga dataset:

# %%
matriculados_2016_df = matriculados_2016_dict['Matriculados_2016']
matriculados_2016_df.head(10)
# Out:
#                     MINISTERIO DE EDUCACIÓN NACIONAL  ...        Unnamed: 32
# 0  MATRICULADOS EN EDUCACIÓN SUPERIOR - COLOMBIA ...  ...                NaN
# 1  Fecha de corte de la información: Mayo 15 de 2017  ...                NaN
# 2  Fuente: Ministerio de Educación Nacional - Sis...  ...                NaN
# 3  La información suministrada corresponde a lo r...  ...                NaN
# 4                                                NaN  ...                NaN
# 5                         Código de \nla Institución  ...  Matriculados 2016
# 6                                               1101  ...                410
# 7                                               1101  ...                428
# 8                                               1101  ...                196
# 9                                               1101  ...                215
#
# [10 rows x 33 columns]

# %%
matriculados_2016_df["Unnamed: 11"].value_counts()
# Out:
# SANTAFE DE BOGOTA                    32731
# MEDELLIN                              7038
# CALI                                  2696
# BUCARAMANGA                           2149
# BARRANQUILLA                          1977
#                                      ...
# PUERTO BERRIO                           10
# SIBUNDOY                                10
# LETICIA                                  9
# COVEAS (SUCRE)                           4
# Municipio de\ndomicilio de la IES        1
# Name: Unnamed: 11, Length: 73, dtype: int64

# %% [markdown]
# Definir diccionario con los nombres de las columnas que se quieren cambiar:

# %%
rename_columns_dict = {
 "Unnamed: 2": 'INSTITUCION DE EDUCACION SUPERIOR (IES)',
 "Unnamed: 17": 'NIVEL DE FORMACION',
 "Unnamed: 23": 'NUCLEO BASICO DEL CONOCIMIENTO (NBC)',
 "Unnamed: 32": "MATRICULADOS" 
}

# %% [markdown]
# Limpiar filas vacías:

# %%
matriculados_2016_df.drop(matriculados_2016_df.index[0:6], inplace=True)

# %% [markdown]
# Verificar:

# %%
matriculados_2016_df.head()
# Out:
#    MINISTERIO DE EDUCACIÓN NACIONAL Unnamed: 1  ... Unnamed: 31 Unnamed: 32
# 6                              1101       1101  ...           1         410
# 7                              1101       1101  ...           2         428
# 8                              1101       1101  ...           1         196
# 9                              1101       1101  ...           2         215
# 10                             1101       1101  ...           1         268
#
# [5 rows x 33 columns]

# %%
matriculados_2016_df = matriculados_2016_df.loc[matriculados_2016_df["Unnamed: 11"] == "MEDELLIN", :]

# %%
filtered1_df = matriculados_2016_df.filter(["Unnamed: 2", "Unnamed: 17", "Unnamed: 23", "Unnamed: 32"])

# %% [markdown]
# Verificar:

# %%
filtered1_df
# Out:
#                                     Unnamed: 2  ... Unnamed: 32
# 936           UNIVERSIDAD NACIONAL DE COLOMBIA  ...         159
# 937           UNIVERSIDAD NACIONAL DE COLOMBIA  ...         166
# 938           UNIVERSIDAD NACIONAL DE COLOMBIA  ...         132
# 939           UNIVERSIDAD NACIONAL DE COLOMBIA  ...         145
# 940           UNIVERSIDAD NACIONAL DE COLOMBIA  ...         208
# ...                                        ...  ...         ...
# 60078  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...          12
# 60079  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           8
# 60080  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...          10
# 60081  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...          19
# 60082  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...          30
#
# [7038 rows x 4 columns]

# %% [markdown]
# Renombrar las columnas del dataframe filtrado:

# %%
filtered1_df.rename(columns=rename_columns_dict, inplace=True )

# %% [markdown]
# Verificar:

# %%
filtered1_df.head()
# Out:
#     INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 936        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          159
# 937        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          166
# 938        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          132
# 939        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          145
# 940        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          208
#
# [5 rows x 4 columns]

# %% [markdown]
# Cambiar índices:

# %%
filtered1_df.index = list(range(0, len(filtered1_df.iloc[:, 0])))
filtered1_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          159
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          166
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          132
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          145
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          208
# ...                                       ...  ...          ...
# 7033  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           12
# 7034  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...            8
# 7035  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           10
# 7036  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           19
# 7037  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           30
#
# [7038 rows x 4 columns]

# %%
filtered1_df["AÑO"] = [2016] * len(filtered1_df.iloc[:, 0])
filtered1_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ...   AÑO
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2016
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2016
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2016
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2016
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2016
# ...                                       ...  ...   ...
# 7033  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2016
# 7034  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2016
# 7035  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2016
# 7036  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2016
# 7037  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2016
#
# [7038 rows x 5 columns]

# %%
matriculados_df = filtered1_df.filter(["INSTITUCION DE EDUCACION SUPERIOR (IES)", 
                                       "NIVEL DE FORMACION", 
                                       "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", 
                                       "AÑO", 
                                       "MATRICULADOS"])

# %%
matriculados_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          159
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          166
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          132
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          145
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          208
# ...                                       ...  ...          ...
# 7033  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           12
# 7034  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...            8
# 7035  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           10
# 7036  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           19
# 7037  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           30
#
# [7038 rows x 5 columns]

# %%
matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].replace("Diseño", "Disenio")

# %%
matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].value_counts()
# Out:
# Administración                                           1329
# Contaduría pública                                        688
# Ingeniería de sistemas, telemática y afines               521
# Sin clasificar                                            451
# Educación                                                 427
# Derecho y afines                                          353
# Medicina                                                  294
# Psicología                                                223
# Ingeniería industrial y afines                            183
# Comunicación social, periodismo y afines                  150
# Disenio                                                   141
# Ingeniería civil y afines                                 136
# Artes plásticas, visuales y afines                        120
# Salud pública                                             120
# Economía                                                  116
# Ingeniería mecánica y afines                              108
# Ingeniería electrónica, telecomunicaciones y afines       103
# Ingeniería ambiental, sanitaria y afines                  101
# Otras ingenierías                                          96
# Biología, microbiología y afines                           92
# Agronomía                                                  84
# Odontología                                                81
# Arquitectura                                               77
# Filosofía, teología y afines                               73
# Sociología, trabajo social y afines                        61
# Música                                                     59
# Matemáticas, estadística y afines                          51
# Enfermería                                                 49
# Ciencia política, relaciones internacionales               46
# Ingeniería administrativa y afines                         46
# Ingeniería química y afines                                42
# Medicina veterinaria                                       42
# Química y afines                                           41
# Ingeniería eléctrica y afines                              41
# Lenguas modernas, literatura, linguística y afines         39
# Ingeniería biomédica y afines                              38
# Iingeniería industrial, alimentos y afines                 35
# Geografía, historia                                        32
# Publicidad y afines                                        32
# Terapias                                                   32
# Ingeniería de minas, metalurgia y afines                   32
# Física                                                     32
# Deportes, educación física y recreación                    30
# Artes representativas                                      28
# Bibliotecología, otros de ciencias sociales y humanas      26
# Nutrición y dietética                                      21
# Bacteriología                                              18
# Otros programas asociados a bellas artes                   18
# Zootecnia                                                  14
# Geología, otros programas de ciencias naturales            14
# Antropología y  artes liberales                            12
# Ingeniería agronómica, pecuaria y afines                   12
# Ingeniería agrícola, forestal y afines                     12
# Optometría, otros programas de ciencias de la salud         8
# Instrumentación quirúrgica                                  8
# Name: NUCLEO BASICO DEL CONOCIMIENTO (NBC), dtype: int64

# %%
matriculados_df["NIVEL DE FORMACION"].value_counts()
# Out:
# Universitaria                        2971
# Especialización Universitaria        1380
# Tecnológica                          1034
# Maestría                              989
# Especialización Médico Quirúrgica     260
# Doctorado                             252
# Formación técnica profesional         144
# Especialización Tecnológica             8
# Name: NIVEL DE FORMACION, dtype: int64

# %%
matriculados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"].value_counts()
# Out:
# UNIVERSIDAD DE ANTIOQUIA                                   1331
# CORPORACION UNIVERSITARIA REMINGTON                        1283
# UNIVERSIDAD PONTIFICIA BOLIVARIANA                          605
# UNIVERSIDAD EAFIT-                                          430
# UNIVERSIDAD DE MEDELLIN                                     424
# UNIVERSIDAD NACIONAL DE COLOMBIA                            403
# UNIVERSIDAD CES                                             335
# UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM                      294
# TECNOLOGICO DE ANTIOQUIA                                    240
# POLITECNICO COLOMBIANO JAIME ISAZA CADAVID                  216
# UNIVERSIDAD DE SAN BUENAVENTURA                             162
# INSTITUTO TECNOLOGICO METROPOLITANO                         154
# UNIVERSIDAD COOPERATIVA DE COLOMBIA                         126
# FUNDACION UNIVERSITARIA BELLAS ARTES                        123
# INSTITUCIÓN UNIVERSITARIA PASCUAL BRAVO                     113
# INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA                105
# UNIVERSIDAD AUTONOMA LATINOAMERICANA-UNAULA-                100
# FUNDACION UNIVERSITARIA AUTONOMA DE LAS AMERICAS             96
# FUNDACION UNIVERSITARIA ESUMER                               78
# FUNDACION ESCUELA COLOMBIANA DE MERCADOTECNIA -ESCOLME-      76
# UNIVERSIDAD EIA                                              63
# CORPORACION UNIVERSITARIA ADVENTISTA - UNAC                  55
# FUNDACION UNIVERSITARIA MARIA CANO                           51
# COLEGIO MAYOR DE ANTIOQUIA                                   51
# CORPORACION ACADEMIA SUPERIOR DE ARTES                       38
# CORPORACION COLEGIATURA COLOMBIANA                           32
# CORPORACION UNIVERSITARIA U DE COLOMBIA                      18
# ESCUELA DE TECNOLOGIAS DE ANTIOQUIA -ETA-                    16
# FUNDACION UNIVERSITARIA SEMINARIO BIBLICO DE COLOMBIA        12
# CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA -ATEC-           8
# Name: INSTITUCION DE EDUCACION SUPERIOR (IES), dtype: int64

# %%
matriculados_df["MATRICULADOS"].isnull().value_counts()
# Out:
# False    7038
# Name: MATRICULADOS, dtype: int64

# %%
stem_nbc_ls = [
              "INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES", 
              "INGENIERIA INDUSTRIAL Y AFINES ",
              "ECONOMIA",
              "INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES",
              "INGENIERIA AMBIENTAL, SANITARIA Y AFINES",             
              "INGENIERIA CIVIL Y AFINES",
              "INGENIERIA MECANICA Y AFINES",
              "BIOLOGIA, MICROBIOLOGIA Y AFINES",
              "INGENIERIA ELECTRICA Y AFINES",
              "INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES",
              "QUIMICA Y AFINES",
              "OTRAS INGENIERIAS",
              "MATEMATICAS, ESTADISTICA Y AFINES",
              "INGENIERIA QUIMICA Y AFINES",
              "INGENIERIA AGRONOMICA, PECUARIA Y AFINES",
              "INGENIERIA AGRICOLA, FORESTAL Y AFINES",
              "INGENIERIA DE MINAS, METALURGIA Y AFINES",
              "INGENIERIA ADMINISTRATIVA Y AFINES",
              "BACTERIOLOGIA",
              "GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES",
              "FISICA",
              "INGENIERIA BIOMEDICA Y AFINES",
              "INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES",
              "DISENIO"
]

# %%
nbc_base_dict = calligraphy_unification(stem_nbc_ls)
nbc_dict = calligraphy_unification(matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"])
ies_dict = calligraphy_unification(matriculados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"])
nf_dict = calligraphy_unification(matriculados_df["NIVEL DE FORMACION"])

# %%
matriculados1_df = pd.DataFrame()

# %%
for row_num in range(0, len(matriculados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"])):
  initial_str = matriculados_df.loc[row_num,"INSTITUCION DE EDUCACION SUPERIOR (IES)"]
  if initial_str in ies_dict.keys():
    matriculados1_df.loc[row_num, "INSTITUCION DE EDUCACION SUPERIOR (IES)"] = ies_dict[initial_str]

# %%
for row_num in range(0, len(matriculados_df["NIVEL DE FORMACION"])):
  initial_str = matriculados_df.loc[row_num,"NIVEL DE FORMACION"]
  if initial_str in nf_dict.keys():
    matriculados1_df.loc[row_num, "NIVEL DE FORMACION"] = nf_dict[initial_str]

# %%
for row_num in range(0, len(matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"])):
  initial_str = matriculados_df.loc[row_num,"NUCLEO BASICO DEL CONOCIMIENTO (NBC)"]
  if initial_str in nbc_dict.keys():
    matriculados_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = nbc_dict[initial_str]
  if matriculados_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] in nbc_base_dict.values():
    matriculados1_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = matriculados_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] 
  else:
    matriculados1_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = "Null"

# %%
matriculados1_df["AÑO"] =  matriculados_df["AÑO"]
matriculados1_df["MATRICULADOS"] =  matriculados_df["MATRICULADOS"]

# %%
matriculados1_df = matriculados1_df.loc[matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] != "Null", :]

# %%
matriculados1_df.index = list(range(0, len(matriculados1_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"])))

# %%
matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].value_counts()
# Out:
# INGENIERIA DE SISTEMAS TELEMATICA Y AFINES            521
# DISENIO                                               141
# INGENIERIA CIVIL Y AFINES                             136
# ECONOMIA                                              116
# INGENIERIA MECANICA Y AFINES                          108
# INGENIERIA ELECTRONICA TELECOMUNICACIONES Y AFINES    103
# INGENIERIA AMBIENTAL SANITARIA Y AFINES               101
# OTRAS INGENIERIAS                                      96
# BIOLOGIA MICROBIOLOGIA Y AFINES                        92
# MATEMATICAS ESTADISTICA Y AFINES                       51
# INGENIERIA ADMINISTRATIVA Y AFINES                     46
# INGENIERIA QUIMICA Y AFINES                            42
# INGENIERIA ELECTRICA Y AFINES                          41
# QUIMICA Y AFINES                                       41
# INGENIERIA BIOMEDICA Y AFINES                          38
# FISICA                                                 32
# INGENIERIA DE MINAS METALURGIA Y AFINES                32
# BACTERIOLOGIA                                          18
# GEOLOGIA OTROS PROGRAMAS DE CIENCIAS NATURALES         14
# INGENIERIA AGRICOLA FORESTAL Y AFINES                  12
# INGENIERIA AGRONOMICA PECUARIA Y AFINES                12
# Name: NUCLEO BASICO DEL CONOCIMIENTO (NBC), dtype: int64

# %%
sum = 0
resta = 0
for valor in matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"]:
  if valor in nbc_base_dict.values():
    sum = sum + 1
  else:
    resta = resta + 1  
print(sum, resta)
# Out:
# 1793 0

# %% [markdown]
# Volver a poner las comas en la columna de NBC:

# %%
nbc_base_dict
# Out:
# {'BACTERIOLOGIA': 'BACTERIOLOGIA',
#  'BIOLOGIA, MICROBIOLOGIA Y AFINES': 'BIOLOGIA MICROBIOLOGIA Y AFINES',
#  'DISENIO': 'DISENIO',
#  'ECONOMIA': 'ECONOMIA',
#  'FISICA': 'FISICA',
#  'GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES': 'GEOLOGIA OTROS PROGRAMAS DE CIENCIAS NATURALES',
#  'INGENIERIA ADMINISTRATIVA Y AFINES': 'INGENIERIA ADMINISTRATIVA Y AFINES',
#  'INGENIERIA AGRICOLA, FORESTAL Y AFINES': 'INGENIERIA AGRICOLA FORESTAL Y AFINES',
#  'INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES': 'INGENIERIA AGROINDUSTRIAL ALIMENTOS Y AFINES',
#  'INGENIERIA AGRONOMICA, PECUARIA Y AFINES': 'INGENIERIA AGRONOMICA PECUARIA Y AFINES',
#  'INGENIERIA AMBIENTAL, SANITARIA Y AFINES': 'INGENIERIA AMBIENTAL SANITARIA Y AFINES',
#  'INGENIERIA BIOMEDICA Y AFINES': 'INGENIERIA BIOMEDICA Y AFINES',
#  'INGENIERIA CIVIL Y AFINES': 'INGENIERIA CIVIL Y AFINES',
#  'INGENIERIA DE MINAS, METALURGIA Y AFINES': 'INGENIERIA DE MINAS METALURGIA Y AFINES',
#  'INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES': 'INGENIERIA DE SISTEMAS TELEMATICA Y AFINES',
#  'INGENIERIA ELECTRICA Y AFINES': 'INGENIERIA ELECTRICA Y AFINES',
#  'INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES': 'INGENIERIA ELECTRONICA TELECOMUNICACIONES Y AFINES',
#  'INGENIERIA INDUSTRIAL Y AFINES ': 'INGENIERIA INDUSTRIAL Y AFINES ',
#  'INGENIERIA MECANICA Y AFINES': 'INGENIERIA MECANICA Y AFINES',
#  'INGENIERIA QUIMICA Y AFINES': 'INGENIERIA QUIMICA Y AFINES',
#  'MATEMATICAS, ESTADISTICA Y AFINES': 'MATEMATICAS ESTADISTICA Y AFINES',
#  'OTRAS INGENIERIAS': 'OTRAS INGENIERIAS',
#  'QUIMICA Y AFINES': 'QUIMICA Y AFINES'}

# %%
coma_dict = dict()
for key, value in nbc_base_dict.items():
  coma_dict[value] = key

coma_dict
# Out:
# {'BACTERIOLOGIA': 'BACTERIOLOGIA',
#  'BIOLOGIA MICROBIOLOGIA Y AFINES': 'BIOLOGIA, MICROBIOLOGIA Y AFINES',
#  'DISENIO': 'DISENIO',
#  'ECONOMIA': 'ECONOMIA',
#  'FISICA': 'FISICA',
#  'GEOLOGIA OTROS PROGRAMAS DE CIENCIAS NATURALES': 'GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES',
#  'INGENIERIA ADMINISTRATIVA Y AFINES': 'INGENIERIA ADMINISTRATIVA Y AFINES',
#  'INGENIERIA AGRICOLA FORESTAL Y AFINES': 'INGENIERIA AGRICOLA, FORESTAL Y AFINES',
#  'INGENIERIA AGROINDUSTRIAL ALIMENTOS Y AFINES': 'INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES',
#  'INGENIERIA AGRONOMICA PECUARIA Y AFINES': 'INGENIERIA AGRONOMICA, PECUARIA Y AFINES',
#  'INGENIERIA AMBIENTAL SANITARIA Y AFINES': 'INGENIERIA AMBIENTAL, SANITARIA Y AFINES',
#  'INGENIERIA BIOMEDICA Y AFINES': 'INGENIERIA BIOMEDICA Y AFINES',
#  'INGENIERIA CIVIL Y AFINES': 'INGENIERIA CIVIL Y AFINES',
#  'INGENIERIA DE MINAS METALURGIA Y AFINES': 'INGENIERIA DE MINAS, METALURGIA Y AFINES',
#  'INGENIERIA DE SISTEMAS TELEMATICA Y AFINES': 'INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES',
#  'INGENIERIA ELECTRICA Y AFINES': 'INGENIERIA ELECTRICA Y AFINES',
#  'INGENIERIA ELECTRONICA TELECOMUNICACIONES Y AFINES': 'INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES',
#  'INGENIERIA INDUSTRIAL Y AFINES ': 'INGENIERIA INDUSTRIAL Y AFINES ',
#  'INGENIERIA MECANICA Y AFINES': 'INGENIERIA MECANICA Y AFINES',
#  'INGENIERIA QUIMICA Y AFINES': 'INGENIERIA QUIMICA Y AFINES',
#  'MATEMATICAS ESTADISTICA Y AFINES': 'MATEMATICAS, ESTADISTICA Y AFINES',
#  'OTRAS INGENIERIAS': 'OTRAS INGENIERIAS',
#  'QUIMICA Y AFINES': 'QUIMICA Y AFINES'}

# %%
for row_num in range(0, len(matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"])):
  key = matriculados1_df.loc[row_num,"NUCLEO BASICO DEL CONOCIMIENTO (NBC)"]
  if key in coma_dict.keys():
    matriculados1_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = coma_dict[key]

# %%
matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].value_counts()
# Out:
# INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES            521
# DISENIO                                                141
# INGENIERIA CIVIL Y AFINES                              136
# ECONOMIA                                               116
# INGENIERIA MECANICA Y AFINES                           108
# INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES    103
# INGENIERIA AMBIENTAL, SANITARIA Y AFINES               101
# OTRAS INGENIERIAS                                       96
# BIOLOGIA, MICROBIOLOGIA Y AFINES                        92
# MATEMATICAS, ESTADISTICA Y AFINES                       51
# INGENIERIA ADMINISTRATIVA Y AFINES                      46
# INGENIERIA QUIMICA Y AFINES                             42
# QUIMICA Y AFINES                                        41
# INGENIERIA ELECTRICA Y AFINES                           41
# INGENIERIA BIOMEDICA Y AFINES                           38
# FISICA                                                  32
# INGENIERIA DE MINAS, METALURGIA Y AFINES                32
# BACTERIOLOGIA                                           18
# GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES         14
# INGENIERIA AGRICOLA, FORESTAL Y AFINES                  12
# INGENIERIA AGRONOMICA, PECUARIA Y AFINES                12
# Name: NUCLEO BASICO DEL CONOCIMIENTO (NBC), dtype: int64

# %%
matriculados1_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          159
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          166
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          132
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          145
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          208
# ...                                       ...  ...          ...
# 1788     FUNDACION UNIVERSITARIA BELLAS ARTES  ...            1
# 1789     FUNDACION UNIVERSITARIA BELLAS ARTES  ...            1
# 1790     FUNDACION UNIVERSITARIA BELLAS ARTES  ...            1
# 1791  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           16
# 1792  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           12
#
# [1793 rows x 5 columns]

# %%
# !mkdir /content/WTM_Medellin_Pilot/Piloto_Medellin/data/clean

# %%
matriculados1_df.to_csv("/content/WTM_Medellin_Pilot/Piloto_Medellin/data/clean/matriculados_2016.csv", index=False)
