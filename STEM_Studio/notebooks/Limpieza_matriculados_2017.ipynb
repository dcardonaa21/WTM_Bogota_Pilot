# %% [markdown]
# MÉTRICA:
# *   Cobertura de los programas académicos de tecnología en Medellín.
#
# DATOS:
#
# *   Número de estudiantes y número de graduados por programa académico
# *   Año
# *   Cobertura

# %%
# !git clone "http://github.com/dcardonaa21/WTM_Medellin_Pilot.git"
# Out:
# fatal: destination path 'WTM_Medellin_Pilot' already exists and is not an empty directory.

# %%
import sys 
sys.path.insert(0, "/content/WTM_Medellin_Pilot/STEM_Studio")
sys.path.insert(1, "/content/WTM_Medellin_Pilot/Piloto_Medellin")
import stem_library as sl
import libreria_piloto_medellin as lpm
import pandas as pd
import pathlib
import numpy as np

# %%
def calligraphy_unification(names_ls):
    """
    Replaces every spanish accentuated vowel by a simple vowel, takes "*" out from the string and turns the strings into uppercase strings.
    Parameters:
    names_ls: List of strings.
    Returns:
    names_dict: A dictionary with the original strings as keys and uppercase clean strings as values.
    """
    invalid_vowels_dict = {"á":"a", "é":"e", "í":"i", "ó":"o", "ú":"u", "ü":"u", "Á":"A", "É":"E", "Í":"I", "Ó":"O", "Ú":"U", "Ü":"U", "*":"", ",":"", "-":""}
    characters_ls = []
    new_characters_ls = []
    names_dict = dict()
    new_name = str()
    for name in names_ls:
        characters_ls = list(name)
        for character in characters_ls:
            if character in invalid_vowels_dict.keys():
                new_char = invalid_vowels_dict[character]
                new_characters_ls.append(new_char)
            else:
                new_characters_ls.append(character)
        new_name = ("".join(new_characters_ls)).upper()
        names_dict[name] = new_name
        new_name = str()
        new_characters_ls= []
        characters_ls = []
    return names_dict

# %%
matriculados_2017_dict = pd.read_excel("https://storage.googleapis.com/piloto_medellin/excel/MATRICULADOS-2017.xlsx", sheet_name=None)

# %% [markdown]
# Ver pestañas del archivo de excel:

# %%
matriculados_2017_dict.keys()
# Out:
# dict_keys(['Matriculados_2017'])

# %% [markdown]
# Definir dataframe que contenga dataset:

# %%
matriculados_2017_df = matriculados_2017_dict['Matriculados_2017']
matriculados_2017_df.head(10)
# Out:
#                     MINISTERIO DE EDUCACIÓN NACIONAL  ...        Unnamed: 32
# 0  MATRICULADOS EN EDUCACIÓN SUPERIOR - COLOMBIA ...  ...                NaN
# 1  Fecha de corte de la información: Abril 6 de 2018  ...                NaN
# 2  Fuente: Ministerio de Educación Nacional - Sis...  ...                NaN
# 3  La información suministrada corresponde a lo r...  ...                NaN
# 4                                                NaN  ...                NaN
# 5                         Código de \nla Institución  ...  Matriculados 2017
# 6                                               1101  ...                451
# 7                                               1101  ...                437
# 8                                               1101  ...                237
# 9                                               1101  ...                247
#
# [10 rows x 33 columns]

# %%
matriculados_2017_df["Unnamed: 11"].value_counts()
# Out:
# BOGOTA D.C.                          36739
# MEDELLIN                              6718
# CALI                                  2783
# BARRANQUILLA                          2329
# BUCARAMANGA                           2172
#                                      ...
# CHIQUINQUIRA                            14
# LETICIA                                 10
# PUERTO BERRIO                            9
# COVEAS (SUCRE)                           4
# Municipio de\ndomicilio de la IES        1
# Name: Unnamed: 11, Length: 72, dtype: int64

# %% [markdown]
# Definir diccionario con los nombres de las columnas que se quieren cambiar:

# %%
rename_columns_dict = {
 "Unnamed: 2": 'INSTITUCION DE EDUCACION SUPERIOR (IES)',
 "Unnamed: 17": 'NIVEL DE FORMACION',
 "Unnamed: 23": 'NUCLEO BASICO DEL CONOCIMIENTO (NBC)',
 "Unnamed: 32": "MATRICULADOS" 
}

# %% [markdown]
# Limpiar filas vacías:

# %%
matriculados_2017_df.drop(matriculados_2017_df.index[0:6], inplace=True)

# %% [markdown]
# Verificar:

# %%
matriculados_2017_df.head()
# Out:
#    MINISTERIO DE EDUCACIÓN NACIONAL Unnamed: 1  ... Unnamed: 31 Unnamed: 32
# 6                              1101       1101  ...           1         451
# 7                              1101       1101  ...           2         437
# 8                              1101       1101  ...           1         237
# 9                              1101       1101  ...           2         247
# 10                             1101       1101  ...           1         278
#
# [5 rows x 33 columns]

# %%
matriculados_2017_df = matriculados_2017_df.loc[matriculados_2017_df["Unnamed: 11"] == "MEDELLIN", :]

# %%
filtered1_df = matriculados_2017_df.filter(["Unnamed: 2", "Unnamed: 17", "Unnamed: 23", "Unnamed: 32"])

# %% [markdown]
# Verificar:

# %%
filtered1_df
# Out:
#                                     Unnamed: 2  ... Unnamed: 32
# 931           UNIVERSIDAD NACIONAL DE COLOMBIA  ...         179
# 932           UNIVERSIDAD NACIONAL DE COLOMBIA  ...         181
# 933           UNIVERSIDAD NACIONAL DE COLOMBIA  ...         140
# 934           UNIVERSIDAD NACIONAL DE COLOMBIA  ...         140
# 935           UNIVERSIDAD NACIONAL DE COLOMBIA  ...         202
# ...                                        ...  ...         ...
# 65160  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...          28
# 65161  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           8
# 65162  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           8
# 65163  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...          37
# 65164  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...          31
#
# [6718 rows x 4 columns]

# %% [markdown]
# Renombrar las columnas del dataframe filtrado:

# %%
filtered1_df.rename(columns=rename_columns_dict, inplace=True )

# %% [markdown]
# Verificar:

# %%
filtered1_df.head()
# Out:
#     INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 931        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          179
# 932        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          181
# 933        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          140
# 934        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          140
# 935        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          202
#
# [5 rows x 4 columns]

# %% [markdown]
# Cambiar índices:

# %%
filtered1_df.index = list(range(0, len(filtered1_df.iloc[:, 0])))
filtered1_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          179
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          181
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          140
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          140
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          202
# ...                                       ...  ...          ...
# 6713  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           28
# 6714  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...            8
# 6715  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...            8
# 6716  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           37
# 6717  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           31
#
# [6718 rows x 4 columns]

# %%
filtered1_df["AÑO"] = [2017] * len(filtered1_df.iloc[:, 0])
filtered1_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ...   AÑO
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2017
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2017
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2017
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2017
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2017
# ...                                       ...  ...   ...
# 6713  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2017
# 6714  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2017
# 6715  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2017
# 6716  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2017
# 6717  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2017
#
# [6718 rows x 5 columns]

# %%
matriculados_df = filtered1_df.filter(["INSTITUCION DE EDUCACION SUPERIOR (IES)", 
                                       "NIVEL DE FORMACION", 
                                       "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", 
                                       "AÑO", 
                                       "MATRICULADOS"])

# %%
matriculados_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          179
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          181
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          140
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          140
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          202
# ...                                       ...  ...          ...
# 6713  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           28
# 6714  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...            8
# 6715  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...            8
# 6716  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           37
# 6717  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           31
#
# [6718 rows x 5 columns]

# %%
matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].value_counts()
# Out:
# Administración                                           1226
# Contaduría pública                                        645
# Ingeniería de sistemas, telemática y afines               473
# Sin clasificar                                            463
# Educación                                                 444
# Derecho y afines                                          392
# Medicina                                                  279
# Psicología                                                207
# Ingeniería industrial y afines                            161
# Comunicación social, periodismo y afines                  135
# Ingeniería civil y afines                                 129
# Salud pública                                             118
# Ingeniería ambiental, sanitaria y afines                  110
# Diseño                                                    109
# Economía                                                  106
# Ingeniería mecánica y afines                               98
# Otras ingenierías                                          97
# Ingeniería electrónica, telecomunicaciones y afines        93
# Biología, microbiología y afines                           88
# Odontología                                                82
# Agronomía                                                  77
# Arquitectura                                               75
# Filosofía, teología y afines                               68
# Artes plásticas, visuales y afines                         67
# Sociología, trabajo social y afines                        60
# Enfermería                                                 55
# Matemáticas, estadística y afines                          52
# Iingeniería industrial, alimentos y afines                 51
# Ciencia política, relaciones internacionales               50
# Medicina veterinaria                                       48
# Ingeniería química y afines                                44
# Ingeniería eléctrica y afines                              42
# Ingeniería administrativa y afines                         42
# Lenguas modernas, literatura, linguística y afines         40
# Música                                                     40
# Química y afines                                           38
# Artes representativas                                      36
# Publicidad y afines                                        35
# Ingeniería de minas, metalurgia y afines                   33
# Física                                                     32
# Geografía, historia                                        32
# Terapias                                                   31
# Ingeniería biomédica y afines                              28
# Bibliotecología, otros de ciencias sociales y humanas      27
# Nutrición y dietética                                      23
# Deportes, educación física y recreación                    23
# Otros programas asociados a bellas artes                   20
# Bacteriología                                              16
# Geología, otros programas de ciencias naturales            16
# Antropología y  artes liberales                            12
# Zootecnia                                                  12
# Ingeniería agrícola, forestal y afines                     12
# Ingeniería agronómica, pecuaria y afines                   10
# Optometría, otros programas de ciencias de la salud         8
# Instrumentación quirúrgica                                  8
# Name: NUCLEO BASICO DEL CONOCIMIENTO (NBC), dtype: int64

# %%
matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].replace("Diseño", "Disenio")

# %%
matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].value_counts()
# Out:
# Administración                                           1226
# Contaduría pública                                        645
# Ingeniería de sistemas, telemática y afines               473
# Sin clasificar                                            463
# Educación                                                 444
# Derecho y afines                                          392
# Medicina                                                  279
# Psicología                                                207
# Ingeniería industrial y afines                            161
# Comunicación social, periodismo y afines                  135
# Ingeniería civil y afines                                 129
# Salud pública                                             118
# Ingeniería ambiental, sanitaria y afines                  110
# Disenio                                                   109
# Economía                                                  106
# Ingeniería mecánica y afines                               98
# Otras ingenierías                                          97
# Ingeniería electrónica, telecomunicaciones y afines        93
# Biología, microbiología y afines                           88
# Odontología                                                82
# Agronomía                                                  77
# Arquitectura                                               75
# Filosofía, teología y afines                               68
# Artes plásticas, visuales y afines                         67
# Sociología, trabajo social y afines                        60
# Enfermería                                                 55
# Matemáticas, estadística y afines                          52
# Iingeniería industrial, alimentos y afines                 51
# Ciencia política, relaciones internacionales               50
# Medicina veterinaria                                       48
# Ingeniería química y afines                                44
# Ingeniería eléctrica y afines                              42
# Ingeniería administrativa y afines                         42
# Lenguas modernas, literatura, linguística y afines         40
# Música                                                     40
# Química y afines                                           38
# Artes representativas                                      36
# Publicidad y afines                                        35
# Ingeniería de minas, metalurgia y afines                   33
# Física                                                     32
# Geografía, historia                                        32
# Terapias                                                   31
# Ingeniería biomédica y afines                              28
# Bibliotecología, otros de ciencias sociales y humanas      27
# Deportes, educación física y recreación                    23
# Nutrición y dietética                                      23
# Otros programas asociados a bellas artes                   20
# Bacteriología                                              16
# Geología, otros programas de ciencias naturales            16
# Zootecnia                                                  12
# Antropología y  artes liberales                            12
# Ingeniería agrícola, forestal y afines                     12
# Ingeniería agronómica, pecuaria y afines                   10
# Instrumentación quirúrgica                                  8
# Optometría, otros programas de ciencias de la salud         8
# Name: NUCLEO BASICO DEL CONOCIMIENTO (NBC), dtype: int64

# %%
matriculados_df["NIVEL DE FORMACION"].value_counts()
# Out:
# Universitaria                        2876
# Especialización Universitaria        1368
# Maestría                             1010
# Tecnológica                           844
# Doctorado                             268
# Especialización Médico Quirúrgica     245
# Formación técnica profesional         103
# Especialización Tecnológica             4
# Name: NIVEL DE FORMACION, dtype: int64

# %%
matriculados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"].value_counts()
# Out:
# UNIVERSIDAD DE ANTIOQUIA                                   1421
# CORPORACION UNIVERSITARIA REMINGTON                        1227
# UNIVERSIDAD PONTIFICIA BOLIVARIANA                          644
# UNIVERSIDAD DE MEDELLIN                                     422
# UNIVERSIDAD EAFIT-                                          422
# UNIVERSIDAD NACIONAL DE COLOMBIA                            395
# UNIVERSIDAD CES                                             334
# TECNOLOGICO DE ANTIOQUIA                                    239
# UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM                      237
# INSTITUTO TECNOLOGICO METROPOLITANO                         160
# UNIVERSIDAD DE SAN BUENAVENTURA                             150
# UNIVERSIDAD COOPERATIVA DE COLOMBIA                         127
# INSTITUCIÓN UNIVERSITARIA PASCUAL BRAVO                     118
# POLITECNICO COLOMBIANO JAIME ISAZA CADAVID                  109
# UNIVERSIDAD AUTONOMA LATINOAMERICANA-UNAULA-                103
# FUNDACION UNIVERSITARIA AUTONOMA DE LAS AMERICAS            102
# FUNDACION UNIVERSITARIA ESUMER                               79
# FUNDACION ESCUELA COLOMBIANA DE MERCADOTECNIA -ESCOLME-      71
# COLEGIO MAYOR DE ANTIOQUIA                                   66
# FUNDACION UNIVERSITARIA MARIA CANO                           58
# CORPORACION UNIVERSITARIA ADVENTISTA - UNAC                  53
# INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA                 49
# CORPORACION COLEGIATURA COLOMBIANA                           32
# CORPORACION ACADEMIA SUPERIOR DE ARTES                       30
# CORPORACION UNIVERSITARIA U DE COLOMBIA                      20
# FUNDACION UNIVERSITARIA BELLAS ARTES                         20
# ESCUELA DE TECNOLOGIAS DE ANTIOQUIA -ETA-                    14
# FUNDACION UNIVERSITARIA SEMINARIO BIBLICO DE COLOMBIA        12
# CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA -ATEC-           4
# Name: INSTITUCION DE EDUCACION SUPERIOR (IES), dtype: int64

# %%
matriculados_df["MATRICULADOS"].isnull().value_counts()
# Out:
# False    6718
# Name: MATRICULADOS, dtype: int64

# %%
stem_nbc_ls = [
              "INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES", 
              "INGENIERIA INDUSTRIAL Y AFINES ",
              "ECONOMIA",
              "INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES",
              "INGENIERIA AMBIENTAL, SANITARIA Y AFINES",             
              "INGENIERIA CIVIL Y AFINES",
              "INGENIERIA MECANICA Y AFINES",
              "BIOLOGIA, MICROBIOLOGIA Y AFINES",
              "INGENIERIA ELECTRICA Y AFINES",
              "INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES",
              "QUIMICA Y AFINES",
              "OTRAS INGENIERIAS",
              "MATEMATICAS, ESTADISTICA Y AFINES",
              "INGENIERIA QUIMICA Y AFINES",
              "INGENIERIA AGRONOMICA, PECUARIA Y AFINES",
              "INGENIERIA AGRICOLA, FORESTAL Y AFINES",
              "INGENIERIA DE MINAS, METALURGIA Y AFINES",
              "INGENIERIA ADMINISTRATIVA Y AFINES",
              "BACTERIOLOGIA",
              "GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES",
              "FISICA",
              "INGENIERIA BIOMEDICA Y AFINES",
              "INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES",
              "DISENIO"
]

# %%
nbc_base_dict = calligraphy_unification(stem_nbc_ls)
nbc_dict = calligraphy_unification(matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"])
ies_dict = calligraphy_unification(matriculados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"])
nf_dict = calligraphy_unification(matriculados_df["NIVEL DE FORMACION"])

# %%
matriculados1_df = pd.DataFrame()

# %%
for row_num in range(0, len(matriculados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"])):
  initial_str = matriculados_df.loc[row_num,"INSTITUCION DE EDUCACION SUPERIOR (IES)"]
  if initial_str in ies_dict.keys():
    matriculados1_df.loc[row_num, "INSTITUCION DE EDUCACION SUPERIOR (IES)"] = ies_dict[initial_str]

# %%
for row_num in range(0, len(matriculados_df["NIVEL DE FORMACION"])):
  initial_str = matriculados_df.loc[row_num,"NIVEL DE FORMACION"]
  if initial_str in nf_dict.keys():
    matriculados1_df.loc[row_num, "NIVEL DE FORMACION"] = nf_dict[initial_str]

# %%
for row_num in range(0, len(matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"])):
  initial_str = matriculados_df.loc[row_num,"NUCLEO BASICO DEL CONOCIMIENTO (NBC)"]
  if initial_str in nbc_dict.keys():
    matriculados_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = nbc_dict[initial_str]
  if matriculados_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] in nbc_base_dict.values():
    matriculados1_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = matriculados_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] 
  else:
    matriculados1_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = "Null"

# %%
matriculados1_df["AÑO"] =  matriculados_df["AÑO"]
matriculados1_df["MATRICULADOS"] =  matriculados_df["MATRICULADOS"]

# %%
matriculados1_df = matriculados1_df.loc[matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] != "Null", :]

# %%
matriculados1_df.index = list(range(0, len(matriculados1_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"])))

# %%
matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].value_counts()
# Out:
# INGENIERIA DE SISTEMAS TELEMATICA Y AFINES            473
# INGENIERIA CIVIL Y AFINES                             129
# INGENIERIA AMBIENTAL SANITARIA Y AFINES               110
# DISENIO                                               109
# ECONOMIA                                              106
# INGENIERIA MECANICA Y AFINES                           98
# OTRAS INGENIERIAS                                      97
# INGENIERIA ELECTRONICA TELECOMUNICACIONES Y AFINES     93
# BIOLOGIA MICROBIOLOGIA Y AFINES                        88
# MATEMATICAS ESTADISTICA Y AFINES                       52
# INGENIERIA QUIMICA Y AFINES                            44
# INGENIERIA ELECTRICA Y AFINES                          42
# INGENIERIA ADMINISTRATIVA Y AFINES                     42
# QUIMICA Y AFINES                                       38
# INGENIERIA DE MINAS METALURGIA Y AFINES                33
# FISICA                                                 32
# INGENIERIA BIOMEDICA Y AFINES                          28
# BACTERIOLOGIA                                          16
# GEOLOGIA OTROS PROGRAMAS DE CIENCIAS NATURALES         16
# INGENIERIA AGRICOLA FORESTAL Y AFINES                  12
# INGENIERIA AGRONOMICA PECUARIA Y AFINES                10
# Name: NUCLEO BASICO DEL CONOCIMIENTO (NBC), dtype: int64

# %%
sum = 0
resta = 0
for valor in matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"]:
  if valor in nbc_base_dict.values():
    sum = sum + 1
  else:
    resta = resta + 1  
print(sum, resta)
# Out:
# 1668 0

# %% [markdown]
# Volver a poner las comas en la columna de NBC:

# %%
nbc_base_dict
# Out:
# {'BACTERIOLOGIA': 'BACTERIOLOGIA',
#  'BIOLOGIA, MICROBIOLOGIA Y AFINES': 'BIOLOGIA MICROBIOLOGIA Y AFINES',
#  'DISENIO': 'DISENIO',
#  'ECONOMIA': 'ECONOMIA',
#  'FISICA': 'FISICA',
#  'GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES': 'GEOLOGIA OTROS PROGRAMAS DE CIENCIAS NATURALES',
#  'INGENIERIA ADMINISTRATIVA Y AFINES': 'INGENIERIA ADMINISTRATIVA Y AFINES',
#  'INGENIERIA AGRICOLA, FORESTAL Y AFINES': 'INGENIERIA AGRICOLA FORESTAL Y AFINES',
#  'INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES': 'INGENIERIA AGROINDUSTRIAL ALIMENTOS Y AFINES',
#  'INGENIERIA AGRONOMICA, PECUARIA Y AFINES': 'INGENIERIA AGRONOMICA PECUARIA Y AFINES',
#  'INGENIERIA AMBIENTAL, SANITARIA Y AFINES': 'INGENIERIA AMBIENTAL SANITARIA Y AFINES',
#  'INGENIERIA BIOMEDICA Y AFINES': 'INGENIERIA BIOMEDICA Y AFINES',
#  'INGENIERIA CIVIL Y AFINES': 'INGENIERIA CIVIL Y AFINES',
#  'INGENIERIA DE MINAS, METALURGIA Y AFINES': 'INGENIERIA DE MINAS METALURGIA Y AFINES',
#  'INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES': 'INGENIERIA DE SISTEMAS TELEMATICA Y AFINES',
#  'INGENIERIA ELECTRICA Y AFINES': 'INGENIERIA ELECTRICA Y AFINES',
#  'INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES': 'INGENIERIA ELECTRONICA TELECOMUNICACIONES Y AFINES',
#  'INGENIERIA INDUSTRIAL Y AFINES ': 'INGENIERIA INDUSTRIAL Y AFINES ',
#  'INGENIERIA MECANICA Y AFINES': 'INGENIERIA MECANICA Y AFINES',
#  'INGENIERIA QUIMICA Y AFINES': 'INGENIERIA QUIMICA Y AFINES',
#  'MATEMATICAS, ESTADISTICA Y AFINES': 'MATEMATICAS ESTADISTICA Y AFINES',
#  'OTRAS INGENIERIAS': 'OTRAS INGENIERIAS',
#  'QUIMICA Y AFINES': 'QUIMICA Y AFINES'}

# %%
coma_dict = dict()
for key, value in nbc_base_dict.items():
  coma_dict[value] = key

coma_dict
# Out:
# {'BACTERIOLOGIA': 'BACTERIOLOGIA',
#  'BIOLOGIA MICROBIOLOGIA Y AFINES': 'BIOLOGIA, MICROBIOLOGIA Y AFINES',
#  'DISENIO': 'DISENIO',
#  'ECONOMIA': 'ECONOMIA',
#  'FISICA': 'FISICA',
#  'GEOLOGIA OTROS PROGRAMAS DE CIENCIAS NATURALES': 'GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES',
#  'INGENIERIA ADMINISTRATIVA Y AFINES': 'INGENIERIA ADMINISTRATIVA Y AFINES',
#  'INGENIERIA AGRICOLA FORESTAL Y AFINES': 'INGENIERIA AGRICOLA, FORESTAL Y AFINES',
#  'INGENIERIA AGROINDUSTRIAL ALIMENTOS Y AFINES': 'INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES',
#  'INGENIERIA AGRONOMICA PECUARIA Y AFINES': 'INGENIERIA AGRONOMICA, PECUARIA Y AFINES',
#  'INGENIERIA AMBIENTAL SANITARIA Y AFINES': 'INGENIERIA AMBIENTAL, SANITARIA Y AFINES',
#  'INGENIERIA BIOMEDICA Y AFINES': 'INGENIERIA BIOMEDICA Y AFINES',
#  'INGENIERIA CIVIL Y AFINES': 'INGENIERIA CIVIL Y AFINES',
#  'INGENIERIA DE MINAS METALURGIA Y AFINES': 'INGENIERIA DE MINAS, METALURGIA Y AFINES',
#  'INGENIERIA DE SISTEMAS TELEMATICA Y AFINES': 'INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES',
#  'INGENIERIA ELECTRICA Y AFINES': 'INGENIERIA ELECTRICA Y AFINES',
#  'INGENIERIA ELECTRONICA TELECOMUNICACIONES Y AFINES': 'INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES',
#  'INGENIERIA INDUSTRIAL Y AFINES ': 'INGENIERIA INDUSTRIAL Y AFINES ',
#  'INGENIERIA MECANICA Y AFINES': 'INGENIERIA MECANICA Y AFINES',
#  'INGENIERIA QUIMICA Y AFINES': 'INGENIERIA QUIMICA Y AFINES',
#  'MATEMATICAS ESTADISTICA Y AFINES': 'MATEMATICAS, ESTADISTICA Y AFINES',
#  'OTRAS INGENIERIAS': 'OTRAS INGENIERIAS',
#  'QUIMICA Y AFINES': 'QUIMICA Y AFINES'}

# %%
for row_num in range(0, len(matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"])):
  key = matriculados1_df.loc[row_num,"NUCLEO BASICO DEL CONOCIMIENTO (NBC)"]
  if key in coma_dict.keys():
    matriculados1_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = coma_dict[key]

# %%
matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].value_counts()
# Out:
# INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES            473
# INGENIERIA CIVIL Y AFINES                              129
# INGENIERIA AMBIENTAL, SANITARIA Y AFINES               110
# DISENIO                                                109
# ECONOMIA                                               106
# INGENIERIA MECANICA Y AFINES                            98
# OTRAS INGENIERIAS                                       97
# INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES     93
# BIOLOGIA, MICROBIOLOGIA Y AFINES                        88
# MATEMATICAS, ESTADISTICA Y AFINES                       52
# INGENIERIA QUIMICA Y AFINES                             44
# INGENIERIA ELECTRICA Y AFINES                           42
# INGENIERIA ADMINISTRATIVA Y AFINES                      42
# QUIMICA Y AFINES                                        38
# INGENIERIA DE MINAS, METALURGIA Y AFINES                33
# FISICA                                                  32
# INGENIERIA BIOMEDICA Y AFINES                           28
# GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES         16
# BACTERIOLOGIA                                           16
# INGENIERIA AGRICOLA, FORESTAL Y AFINES                  12
# INGENIERIA AGRONOMICA, PECUARIA Y AFINES                10
# Name: NUCLEO BASICO DEL CONOCIMIENTO (NBC), dtype: int64

# %%
matriculados1_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          179
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          181
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          140
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          140
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          202
# ...                                       ...  ...          ...
# 1663     FUNDACION UNIVERSITARIA BELLAS ARTES  ...           82
# 1664  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           16
# 1665  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           17
# 1666  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           29
# 1667  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           28
#
# [1668 rows x 5 columns]

# %%
# !mkdir /content/WTM_Medellin_Pilot/Piloto_Medellin/data/clean
# Out:
# mkdir: cannot create directory ‘/content/WTM_Medellin_Pilot/Piloto_Medellin/data/clean’: File exists

# %%
matriculados1_df.to_csv("/content/WTM_Medellin_Pilot/Piloto_Medellin/data/clean/matriculados_2017.csv", index=False)
