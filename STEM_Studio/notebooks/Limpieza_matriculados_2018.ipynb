# %% [markdown]
# MÉTRICA:
# *   Cobertura de los programas académicos de tecnología en Medellín.
#
# DATOS:
#
# *   Número de estudiantes y número de graduados por programa académico
# *   Año
# *   Cobertura

# %%
# !git clone "http://github.com/dcardonaa21/WTM_Medellin_Pilot.git"
# Out:
# Cloning into 'WTM_Medellin_Pilot'...
# warning: redirecting to https://github.com/dcardonaa21/WTM_Medellin_Pilot.git/
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 93 (delta 6), reused 0 (delta 0), pack-reused 78
# Unpacking objects: 100% (93/93), done.

# %%
import sys 
sys.path.insert(0, "/content/WTM_Medellin_Pilot/STEM_Studio")
sys.path.insert(1, "/content/WTM_Medellin_Pilot/Piloto_Medellin")
import stem_library as sl
import libreria_piloto_medellin as lpm
import pandas as pd
import pathlib
import numpy as np

# %%
def calligraphy_unification(names_ls):
    """
    Replaces every spanish accentuated vowel by a simple vowel, takes "*" out from the string and turns the strings into uppercase strings.
    Parameters:
    names_ls: List of strings.
    Returns:
    names_dict: A dictionary with the original strings as keys and uppercase clean strings as values.
    """
    invalid_vowels_dict = {"á":"a", "é":"e", "í":"i", "ó":"o", "ú":"u", "ü":"u", "Á":"A", "É":"E", "Í":"I", "Ó":"O", "Ú":"U", "Ü":"U", "*":"", ",":"", "-":""}
    characters_ls = []
    new_characters_ls = []
    names_dict = dict()
    new_name = str()
    for name in names_ls:
        characters_ls = list(name)
        for character in characters_ls:
            if character in invalid_vowels_dict.keys():
                new_char = invalid_vowels_dict[character]
                new_characters_ls.append(new_char)
            else:
                new_characters_ls.append(character)
        new_name = ("".join(new_characters_ls)).upper()
        names_dict[name] = new_name
        new_name = str()
        new_characters_ls= []
        characters_ls = []
    return names_dict

# %%
matriculados_2018_dict = pd.read_excel("https://storage.googleapis.com/piloto_medellin/excel/MATRICULADOS-2018.xlsx", sheet_name=None)

# %% [markdown]
# Ver pestañas del archivo de excel:

# %%
matriculados_2018_dict.keys()
# Out:
# dict_keys(['Sheet1'])

# %% [markdown]
# Definir dataframe que contenga dataset:

# %%
matriculados_2018_df = matriculados_2018_dict['Sheet1']
matriculados_2018_df.head(10)
# Out:
#                                           Unnamed: 0  ...        Unnamed: 32
# 0  MATRICULADOS EN EDUCACIÓN SUPERIOR - COLOMBIA ...  ...                NaN
# 1  Fecha de corte de la información: Junio de 201...  ...                NaN
# 2  Fuente: Ministerio de Educación Nacional - Sis...  ...                NaN
# 3  La información suministrada corresponde a lo r...  ...                NaN
# 4                                                NaN  ...                NaN
# 5                         Código de \nla Institución  ...  Matriculados 2018
# 6                                               1101  ...                459
# 7                                               1101  ...                438
# 8                                               1101  ...                238
# 9                                               1101  ...                246
#
# [10 rows x 33 columns]

# %%
matriculados_2018_df["Unnamed: 11"].value_counts()
# Out:
# BOGOTA D.C.                          34428
# MEDELLIN                              6818
# CALI                                  2939
# BARRANQUILLA                          2515
# BUCARAMANGA                           2216
#                                      ...
# SANTA FE DE ANTIOQUIA                   13
# PUERTO BERRIO                            8
# COVEAS (SUCRE)                           6
# LETICIA                                  5
# Municipio de\ndomicilio de la IES        1
# Name: Unnamed: 11, Length: 71, dtype: int64

# %% [markdown]
# Definir diccionario con los nombres de las columnas que se quieren cambiar:

# %%
rename_columns_dict = {
 "Unnamed: 2": 'INSTITUCION DE EDUCACION SUPERIOR (IES)',
 "Unnamed: 17": 'NIVEL DE FORMACION',
 "Unnamed: 23": 'NUCLEO BASICO DEL CONOCIMIENTO (NBC)',
 "Unnamed: 32": "MATRICULADOS" 
}

# %% [markdown]
# Limpiar filas vacías:

# %%
matriculados_2018_df.drop(matriculados_2018_df.index[0:6], inplace=True)

# %% [markdown]
# Verificar:

# %%
matriculados_2018_df.head()
# Out:
#    Unnamed: 0 Unnamed: 1  ... Unnamed: 31 Unnamed: 32
# 6        1101       1101  ...           1         459
# 7        1101       1101  ...           2         438
# 8        1101       1101  ...           1         238
# 9        1101       1101  ...           2         246
# 10       1101       1101  ...           1         286
#
# [5 rows x 33 columns]

# %%
matriculados_2018_df = matriculados_2018_df.loc[matriculados_2018_df["Unnamed: 11"] == "MEDELLIN", :]

# %% [markdown]
# Fraccionar el dataframe en 2 para trabajar con las columnas de los semestres por separado. Filtrar columnas de interés sin los semestres:

# %%
filtered1_df = matriculados_2018_df.filter(["Unnamed: 2", "Unnamed: 17", "Unnamed: 23", "Unnamed: 32"])

# %% [markdown]
# Verificar:

# %%
filtered1_df
# Out:
#                                     Unnamed: 2  ... Unnamed: 32
# 1012          UNIVERSIDAD NACIONAL DE COLOMBIA  ...         188
# 1013          UNIVERSIDAD NACIONAL DE COLOMBIA  ...         183
# 1014          UNIVERSIDAD NACIONAL DE COLOMBIA  ...         146
# 1015          UNIVERSIDAD NACIONAL DE COLOMBIA  ...         158
# 1016          UNIVERSIDAD NACIONAL DE COLOMBIA  ...         221
# ...                                        ...  ...         ...
# 58486  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...          27
# 58487  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...          10
# 58488  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           6
# 58489  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...          12
# 58490  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...          11
#
# [6818 rows x 4 columns]

# %% [markdown]
# Renombrar las columnas del dataframe filtrado:

# %%
filtered1_df.rename(columns=rename_columns_dict, inplace=True )

# %% [markdown]
# Verificar:

# %%
filtered1_df.head()
# Out:
#      INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 1012        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          188
# 1013        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          183
# 1014        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          146
# 1015        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          158
# 1016        UNIVERSIDAD NACIONAL DE COLOMBIA  ...          221
#
# [5 rows x 4 columns]

# %% [markdown]
# Cambiar índices:

# %%
filtered1_df.index = list(range(0, len(filtered1_df.iloc[:, 0])))
filtered1_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          188
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          183
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          146
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          158
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          221
# ...                                       ...  ...          ...
# 6813  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           27
# 6814  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           10
# 6815  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...            6
# 6816  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           12
# 6817  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           11
#
# [6818 rows x 4 columns]

# %%
filtered1_df["AÑO"] = [2018] * len(filtered1_df.iloc[:, 0])
filtered1_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ...   AÑO
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2018
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2018
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2018
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2018
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2018
# ...                                       ...  ...   ...
# 6813  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2018
# 6814  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2018
# 6815  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2018
# 6816  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2018
# 6817  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...  2018
#
# [6818 rows x 5 columns]

# %%
matriculados_df = filtered1_df.filter(["INSTITUCION DE EDUCACION SUPERIOR (IES)", 
                                       "NIVEL DE FORMACION", 
                                       "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", 
                                       "AÑO", 
                                       "MATRICULADOS"])

# %%
matriculados_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          188
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          183
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          146
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          158
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          221
# ...                                       ...  ...          ...
# 6813  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           27
# 6814  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           10
# 6815  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...            6
# 6816  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           12
# 6817  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           11
#
# [6818 rows x 5 columns]

# %%
matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].value_counts()
# Out:
# Administración                                           1339
# Contaduría pública                                        559
# Educación                                                 531
# Ingeniería de sistemas, telemática y afines               442
# Derecho y afines                                          420
# Medicina                                                  323
# Psicología                                                218
# Ingeniería industrial y afines                            175
# Diseño                                                    161
# Salud pública                                             151
# Artes plásticas, visuales y afines                        147
# Ingeniería civil y afines                                 142
# Comunicación social, periodismo y afines                  125
# Ingeniería ambiental, sanitaria y afines                  115
# Economía                                                  107
# Ingeniería electrónica, telecomunicaciones y afines       106
# Sociología, trabajo social y afines                       102
# Biología, microbiología y afines                          102
# Ingeniería mecánica y afines                              102
# Otras ingenierías                                         100
# Arquitectura                                               80
# Odontología                                                80
# Matemáticas, estadística y afines                          78
# Filosofía, teología y afines                               77
# Música                                                     74
# Lenguas modernas, literatura, linguística y afines         58
# Ingeniería agroindustrial, alimentos y afines              51
# Ingeniería administrativa y afines                         51
# Ciencia política, relaciones internacionales               50
# Ingeniería eléctrica y afines                              50
# Medicina veterinaria                                       50
# Enfermería                                                 50
# Ingeniería química y afines                                47
# Agronomía                                                  45
# Química y afines                                           45
# Bibliotecología, otros de ciencias sociales y humanas      40
# Terapias                                                   38
# Publicidad y afines                                        36
# Deportes, educación física y recreación                    34
# Física                                                     33
# Ingeniería de minas, metalurgia y afines                   33
# Geografía, historia                                        30
# Artes representativas                                      29
# Bacteriología                                              28
# Ingeniería biomédica y afines                              28
# Nutrición y dietética                                      24
# Geología, otros programas de ciencias naturales            21
# Otros programas asociados a bellas artes                   20
# Ingeniería agrícola, forestal y afines                     16
# Antropología y  artes liberales                            16
# Zootecnia                                                  12
# Ingeniería agronómica, pecuaria y afines                   12
# Optometría, otros programas de ciencias de la salud         8
# Instrumentación quirúrgica                                  4
# Formación relacionada con el campo militar o policial       3
# Name: NUCLEO BASICO DEL CONOCIMIENTO (NBC), dtype: int64

# %%
matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].replace("Diseño", "Disenio")

# %%
matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].value_counts()
# Out:
# Administración                                           1339
# Contaduría pública                                        559
# Educación                                                 531
# Ingeniería de sistemas, telemática y afines               442
# Derecho y afines                                          420
# Medicina                                                  323
# Psicología                                                218
# Ingeniería industrial y afines                            175
# Disenio                                                   161
# Salud pública                                             151
# Artes plásticas, visuales y afines                        147
# Ingeniería civil y afines                                 142
# Comunicación social, periodismo y afines                  125
# Ingeniería ambiental, sanitaria y afines                  115
# Economía                                                  107
# Ingeniería electrónica, telecomunicaciones y afines       106
# Ingeniería mecánica y afines                              102
# Sociología, trabajo social y afines                       102
# Biología, microbiología y afines                          102
# Otras ingenierías                                         100
# Odontología                                                80
# Arquitectura                                               80
# Matemáticas, estadística y afines                          78
# Filosofía, teología y afines                               77
# Música                                                     74
# Lenguas modernas, literatura, linguística y afines         58
# Ingeniería administrativa y afines                         51
# Ingeniería agroindustrial, alimentos y afines              51
# Ciencia política, relaciones internacionales               50
# Enfermería                                                 50
# Medicina veterinaria                                       50
# Ingeniería eléctrica y afines                              50
# Ingeniería química y afines                                47
# Química y afines                                           45
# Agronomía                                                  45
# Bibliotecología, otros de ciencias sociales y humanas      40
# Terapias                                                   38
# Publicidad y afines                                        36
# Deportes, educación física y recreación                    34
# Física                                                     33
# Ingeniería de minas, metalurgia y afines                   33
# Geografía, historia                                        30
# Artes representativas                                      29
# Ingeniería biomédica y afines                              28
# Bacteriología                                              28
# Nutrición y dietética                                      24
# Geología, otros programas de ciencias naturales            21
# Otros programas asociados a bellas artes                   20
# Ingeniería agrícola, forestal y afines                     16
# Antropología y  artes liberales                            16
# Zootecnia                                                  12
# Ingeniería agronómica, pecuaria y afines                   12
# Optometría, otros programas de ciencias de la salud         8
# Instrumentación quirúrgica                                  4
# Formación relacionada con el campo militar o policial       3
# Name: NUCLEO BASICO DEL CONOCIMIENTO (NBC), dtype: int64

# %%
matriculados_df["NIVEL DE FORMACION"].value_counts()
# Out:
# Universitaria                        3099
# Especialización Universitaria        1330
# Maestría                             1064
# Tecnológica                           733
# Doctorado                             269
# Especialización Médico Quirúrgica     236
# Formación técnica profesional          82
# Especialización Tecnológica             5
# Name: NIVEL DE FORMACION, dtype: int64

# %%
matriculados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"].value_counts()
# Out:
# UNIVERSIDAD DE ANTIOQUIA                                   1347
# CORPORACION UNIVERSITARIA REMINGTON                         984
# UNIVERSIDAD PONTIFICIA BOLIVARIANA                          730
# UNIVERSIDAD EAFIT-                                          412
# UNIVERSIDAD DE MEDELLIN                                     406
# UNIVERSIDAD NACIONAL DE COLOMBIA                            402
# UNIVERSIDAD CES                                             355
# UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM                      241
# TECNOLOGICO DE ANTIOQUIA                                    228
# POLITECNICO COLOMBIANO JAIME ISAZA CADAVID                  189
# INSTITUTO TECNOLOGICO METROPOLITANO                         171
# FUNDACION UNIVERSITARIA BELLAS ARTES                        158
# UNIVERSIDAD DE SAN BUENAVENTURA                             157
# UNIVERSIDAD COOPERATIVA DE COLOMBIA                         127
# INSTITUCIÓN UNIVERSITARIA PASCUAL BRAVO                     121
# INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA                118
# UNIVERSIDAD AUTONOMA LATINOAMERICANA-UNAULA-                109
# FUNDACION UNIVERSITARIA AUTONOMA DE LAS AMERICAS             97
# FUNDACION UNIVERSITARIA ESUMER                               84
# COLEGIO MAYOR DE ANTIOQUIA                                   79
# FUNDACION ESCUELA COLOMBIANA DE MERCADOTECNIA -ESCOLME-      67
# FUNDACION UNIVERSITARIA MARIA CANO                           66
# CORPORACION UNIVERSITARIA ADVENTISTA - UNAC                  62
# CORPORACION COLEGIATURA COLOMBIANA                           31
# CORPORACION ACADEMIA SUPERIOR DE ARTES                       30
# CORPORACION UNIVERSITARIA U DE COLOMBIA                      20
# ESCUELA DE TECNOLOGIAS DE ANTIOQUIA -ETA-                    13
# FUNDACION UNIVERSITARIA SEMINARIO BIBLICO DE COLOMBIA         8
# CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA -ATEC-           6
# Name: INSTITUCION DE EDUCACION SUPERIOR (IES), dtype: int64

# %%
matriculados_df["MATRICULADOS"].isnull().value_counts()
# Out:
# False    6818
# Name: MATRICULADOS, dtype: int64

# %%
stem_nbc_ls = [
              "INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES", 
              "INGENIERIA INDUSTRIAL Y AFINES ",
              "ECONOMIA",
              "INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES",
              "INGENIERIA AMBIENTAL, SANITARIA Y AFINES",             
              "INGENIERIA CIVIL Y AFINES",
              "INGENIERIA MECANICA Y AFINES",
              "BIOLOGIA, MICROBIOLOGIA Y AFINES",
              "INGENIERIA ELECTRICA Y AFINES",
              "INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES",
              "QUIMICA Y AFINES",
              "OTRAS INGENIERIAS",
              "MATEMATICAS, ESTADISTICA Y AFINES",
              "INGENIERIA QUIMICA Y AFINES",
              "INGENIERIA AGRONOMICA, PECUARIA Y AFINES",
              "INGENIERIA AGRICOLA, FORESTAL Y AFINES",
              "INGENIERIA DE MINAS, METALURGIA Y AFINES",
              "INGENIERIA ADMINISTRATIVA Y AFINES",
              "BACTERIOLOGIA",
              "GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES",
              "FISICA",
              "INGENIERIA BIOMEDICA Y AFINES",
              "INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES",
              "DISENIO"
]

# %%
nbc_base_dict = calligraphy_unification(stem_nbc_ls)
nbc_dict = calligraphy_unification(matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"])
ies_dict = calligraphy_unification(matriculados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"])
nf_dict = calligraphy_unification(matriculados_df["NIVEL DE FORMACION"])

# %%
matriculados1_df = pd.DataFrame()

# %%
for row_num in range(0, len(matriculados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"])):
  initial_str = matriculados_df.loc[row_num,"INSTITUCION DE EDUCACION SUPERIOR (IES)"]
  if initial_str in ies_dict.keys():
    matriculados1_df.loc[row_num, "INSTITUCION DE EDUCACION SUPERIOR (IES)"] = ies_dict[initial_str]

# %%
for row_num in range(0, len(matriculados_df["NIVEL DE FORMACION"])):
  initial_str = matriculados_df.loc[row_num,"NIVEL DE FORMACION"]
  if initial_str in nf_dict.keys():
    matriculados1_df.loc[row_num, "NIVEL DE FORMACION"] = nf_dict[initial_str]

# %%
for row_num in range(0, len(matriculados_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"])):
  initial_str = matriculados_df.loc[row_num,"NUCLEO BASICO DEL CONOCIMIENTO (NBC)"]
  if initial_str in nbc_dict.keys():
    matriculados_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = nbc_dict[initial_str]
  if matriculados_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] in nbc_base_dict.values():
    matriculados1_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = matriculados_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] 
  else:
    matriculados1_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = "Null"

# %%
matriculados1_df["AÑO"] =  matriculados_df["AÑO"]
matriculados1_df["MATRICULADOS"] =  matriculados_df["MATRICULADOS"]

# %%
matriculados1_df = matriculados1_df.loc[matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] != "Null", :]

# %%
matriculados1_df.index = list(range(0, len(matriculados1_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"])))

# %%
matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].value_counts()
# Out:
# INGENIERIA DE SISTEMAS TELEMATICA Y AFINES            442
# DISENIO                                               161
# INGENIERIA CIVIL Y AFINES                             142
# INGENIERIA AMBIENTAL SANITARIA Y AFINES               115
# ECONOMIA                                              107
# INGENIERIA ELECTRONICA TELECOMUNICACIONES Y AFINES    106
# BIOLOGIA MICROBIOLOGIA Y AFINES                       102
# INGENIERIA MECANICA Y AFINES                          102
# OTRAS INGENIERIAS                                     100
# MATEMATICAS ESTADISTICA Y AFINES                       78
# INGENIERIA ADMINISTRATIVA Y AFINES                     51
# INGENIERIA AGROINDUSTRIAL ALIMENTOS Y AFINES           51
# INGENIERIA ELECTRICA Y AFINES                          50
# INGENIERIA QUIMICA Y AFINES                            47
# QUIMICA Y AFINES                                       45
# FISICA                                                 33
# INGENIERIA DE MINAS METALURGIA Y AFINES                33
# BACTERIOLOGIA                                          28
# INGENIERIA BIOMEDICA Y AFINES                          28
# GEOLOGIA OTROS PROGRAMAS DE CIENCIAS NATURALES         21
# INGENIERIA AGRICOLA FORESTAL Y AFINES                  16
# INGENIERIA AGRONOMICA PECUARIA Y AFINES                12
# Name: NUCLEO BASICO DEL CONOCIMIENTO (NBC), dtype: int64

# %%
sum = 0
resta = 0
for valor in matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"]:
  if valor in nbc_base_dict.values():
    sum = sum + 1
  else:
    resta = resta + 1  
print(sum, resta)
# Out:
# 1870 0

# %% [markdown]
# Volver a poner las comas en la columna de NBC:

# %%
nbc_base_dict
# Out:
# {'BACTERIOLOGIA': 'BACTERIOLOGIA',
#  'BIOLOGIA, MICROBIOLOGIA Y AFINES': 'BIOLOGIA MICROBIOLOGIA Y AFINES',
#  'DISENIO': 'DISENIO',
#  'ECONOMIA': 'ECONOMIA',
#  'FISICA': 'FISICA',
#  'GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES': 'GEOLOGIA OTROS PROGRAMAS DE CIENCIAS NATURALES',
#  'INGENIERIA ADMINISTRATIVA Y AFINES': 'INGENIERIA ADMINISTRATIVA Y AFINES',
#  'INGENIERIA AGRICOLA, FORESTAL Y AFINES': 'INGENIERIA AGRICOLA FORESTAL Y AFINES',
#  'INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES': 'INGENIERIA AGROINDUSTRIAL ALIMENTOS Y AFINES',
#  'INGENIERIA AGRONOMICA, PECUARIA Y AFINES': 'INGENIERIA AGRONOMICA PECUARIA Y AFINES',
#  'INGENIERIA AMBIENTAL, SANITARIA Y AFINES': 'INGENIERIA AMBIENTAL SANITARIA Y AFINES',
#  'INGENIERIA BIOMEDICA Y AFINES': 'INGENIERIA BIOMEDICA Y AFINES',
#  'INGENIERIA CIVIL Y AFINES': 'INGENIERIA CIVIL Y AFINES',
#  'INGENIERIA DE MINAS, METALURGIA Y AFINES': 'INGENIERIA DE MINAS METALURGIA Y AFINES',
#  'INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES': 'INGENIERIA DE SISTEMAS TELEMATICA Y AFINES',
#  'INGENIERIA ELECTRICA Y AFINES': 'INGENIERIA ELECTRICA Y AFINES',
#  'INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES': 'INGENIERIA ELECTRONICA TELECOMUNICACIONES Y AFINES',
#  'INGENIERIA INDUSTRIAL Y AFINES ': 'INGENIERIA INDUSTRIAL Y AFINES ',
#  'INGENIERIA MECANICA Y AFINES': 'INGENIERIA MECANICA Y AFINES',
#  'INGENIERIA QUIMICA Y AFINES': 'INGENIERIA QUIMICA Y AFINES',
#  'MATEMATICAS, ESTADISTICA Y AFINES': 'MATEMATICAS ESTADISTICA Y AFINES',
#  'OTRAS INGENIERIAS': 'OTRAS INGENIERIAS',
#  'QUIMICA Y AFINES': 'QUIMICA Y AFINES'}

# %%
coma_dict = dict()
for key, value in nbc_base_dict.items():
  coma_dict[value] = key

coma_dict
# Out:
# {'BACTERIOLOGIA': 'BACTERIOLOGIA',
#  'BIOLOGIA MICROBIOLOGIA Y AFINES': 'BIOLOGIA, MICROBIOLOGIA Y AFINES',
#  'DISENIO': 'DISENIO',
#  'ECONOMIA': 'ECONOMIA',
#  'FISICA': 'FISICA',
#  'GEOLOGIA OTROS PROGRAMAS DE CIENCIAS NATURALES': 'GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES',
#  'INGENIERIA ADMINISTRATIVA Y AFINES': 'INGENIERIA ADMINISTRATIVA Y AFINES',
#  'INGENIERIA AGRICOLA FORESTAL Y AFINES': 'INGENIERIA AGRICOLA, FORESTAL Y AFINES',
#  'INGENIERIA AGROINDUSTRIAL ALIMENTOS Y AFINES': 'INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES',
#  'INGENIERIA AGRONOMICA PECUARIA Y AFINES': 'INGENIERIA AGRONOMICA, PECUARIA Y AFINES',
#  'INGENIERIA AMBIENTAL SANITARIA Y AFINES': 'INGENIERIA AMBIENTAL, SANITARIA Y AFINES',
#  'INGENIERIA BIOMEDICA Y AFINES': 'INGENIERIA BIOMEDICA Y AFINES',
#  'INGENIERIA CIVIL Y AFINES': 'INGENIERIA CIVIL Y AFINES',
#  'INGENIERIA DE MINAS METALURGIA Y AFINES': 'INGENIERIA DE MINAS, METALURGIA Y AFINES',
#  'INGENIERIA DE SISTEMAS TELEMATICA Y AFINES': 'INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES',
#  'INGENIERIA ELECTRICA Y AFINES': 'INGENIERIA ELECTRICA Y AFINES',
#  'INGENIERIA ELECTRONICA TELECOMUNICACIONES Y AFINES': 'INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES',
#  'INGENIERIA INDUSTRIAL Y AFINES ': 'INGENIERIA INDUSTRIAL Y AFINES ',
#  'INGENIERIA MECANICA Y AFINES': 'INGENIERIA MECANICA Y AFINES',
#  'INGENIERIA QUIMICA Y AFINES': 'INGENIERIA QUIMICA Y AFINES',
#  'MATEMATICAS ESTADISTICA Y AFINES': 'MATEMATICAS, ESTADISTICA Y AFINES',
#  'OTRAS INGENIERIAS': 'OTRAS INGENIERIAS',
#  'QUIMICA Y AFINES': 'QUIMICA Y AFINES'}

# %%
for row_num in range(0, len(matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"])):
  key = matriculados1_df.loc[row_num,"NUCLEO BASICO DEL CONOCIMIENTO (NBC)"]
  if key in coma_dict.keys():
    matriculados1_df.loc[row_num, "NUCLEO BASICO DEL CONOCIMIENTO (NBC)"] = coma_dict[key]

# %%
matriculados1_df["NUCLEO BASICO DEL CONOCIMIENTO (NBC)"].value_counts()
# Out:
# INGENIERIA DE SISTEMAS, TELEMATICA Y AFINES            442
# DISENIO                                                161
# INGENIERIA CIVIL Y AFINES                              142
# INGENIERIA AMBIENTAL, SANITARIA Y AFINES               115
# ECONOMIA                                               107
# INGENIERIA ELECTRONICA, TELECOMUNICACIONES Y AFINES    106
# INGENIERIA MECANICA Y AFINES                           102
# BIOLOGIA, MICROBIOLOGIA Y AFINES                       102
# OTRAS INGENIERIAS                                      100
# MATEMATICAS, ESTADISTICA Y AFINES                       78
# INGENIERIA AGROINDUSTRIAL, ALIMENTOS Y AFINES           51
# INGENIERIA ADMINISTRATIVA Y AFINES                      51
# INGENIERIA ELECTRICA Y AFINES                           50
# INGENIERIA QUIMICA Y AFINES                             47
# QUIMICA Y AFINES                                        45
# FISICA                                                  33
# INGENIERIA DE MINAS, METALURGIA Y AFINES                33
# BACTERIOLOGIA                                           28
# INGENIERIA BIOMEDICA Y AFINES                           28
# GEOLOGIA, OTROS PROGRAMAS DE CIENCIAS NATURALES         21
# INGENIERIA AGRICOLA, FORESTAL Y AFINES                  16
# INGENIERIA AGRONOMICA, PECUARIA Y AFINES                12
# Name: NUCLEO BASICO DEL CONOCIMIENTO (NBC), dtype: int64

# %%
matriculados1_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          188
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          183
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          146
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          158
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          221
# ...                                       ...  ...          ...
# 1865     FUNDACION UNIVERSITARIA BELLAS ARTES  ...            1
# 1866  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           14
# 1867  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           18
# 1868  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           28
# 1869  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           27
#
# [1870 rows x 5 columns]

# %%
# !mkdir /content/WTM_Medellin_Pilot/Piloto_Medellin/data/clean

# %%
matriculados1_df.to_csv("/content/WTM_Medellin_Pilot/Piloto_Medellin/data/clean/matriculados_2018.csv", index=False)
