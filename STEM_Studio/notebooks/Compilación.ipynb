# %%
import pandas as pd

# %%
graduados_2001_2016 = pd.read_csv("https://storage.googleapis.com/piloto_medellin/clean_csv/graduados_2001_2016.csv")
graduados_2018 = pd.read_csv("https://storage.googleapis.com/piloto_medellin/clean_csv/graduados_2018.csv")
graduados_2019 = pd.read_csv("https://storage.googleapis.com/piloto_medellin/clean_csv/graduados_2019.csv")

matriculados_2001_2013_df = pd.read_csv("https://storage.googleapis.com/piloto_medellin/clean_csv/matriculados_2001_2013.csv")
matriculados_2014_df = pd.read_csv("https://storage.googleapis.com/piloto_medellin/clean_csv/matriculados_2014.csv")
matriculados_2015_df = pd.read_csv("https://storage.googleapis.com/piloto_medellin/clean_csv/matriculados_2015.csv")
matriculados_2016_df = pd.read_csv("https://storage.googleapis.com/piloto_medellin/clean_csv/matriculados_2016.csv")
matriculados_2017_df = pd.read_csv("https://storage.googleapis.com/piloto_medellin/clean_csv/matriculados_2017.csv")
matriculados_2018_df = pd.read_csv("https://storage.googleapis.com/piloto_medellin/clean_csv/matriculados_2018.csv")
matriculados_2019_df = pd.read_csv("https://storage.googleapis.com/piloto_medellin/clean_csv/matriculados_2019.csv")

# %%
matriculados_2001_2013_df
# Out:
#                INSTITUCION DE EDUCACION SUPERIOR (IES)  ...  2013
# 0                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...   640
# 1                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...   615
# 2                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...   536
# 3                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...  1628
# 4                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...   678
# ..                                                 ...  ...   ...
# 748  CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA ATEC  ...     0
# 749  CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA ATEC  ...     0
# 750             CORPORACION ACADEMIA SUPERIOR DE ARTES  ...     0
# 751               SERVICIO NACIONAL DE APRENDIZAJESENA  ...     0
# 752               SERVICIO NACIONAL DE APRENDIZAJESENA  ...     0
#
# [753 rows x 16 columns]

# %%
matriculados_2001_df = pd.DataFrame() 
matriculados_2002_df = pd.DataFrame()
matriculados_2003_df = pd.DataFrame()
matriculados_2004_df = pd.DataFrame()
matriculados_2005_df = pd.DataFrame()
matriculados_2006_df = pd.DataFrame()
matriculados_2007_df = pd.DataFrame()
matriculados_2008_df = pd.DataFrame()
matriculados_2009_df = pd.DataFrame()
matriculados_2010_df = pd.DataFrame()
matriculados_2011_df = pd.DataFrame()
matriculados_2012_df = pd.DataFrame()
matriculados_2013_df = pd.DataFrame()

matriculados_2001_df = matriculados_2001_2013_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "2001"]] 
matriculados_2002_df = matriculados_2001_2013_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "2002"]]
matriculados_2003_df = matriculados_2001_2013_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "2003"]]
matriculados_2004_df = matriculados_2001_2013_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "2004"]]
matriculados_2005_df = matriculados_2001_2013_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "2005"]]
matriculados_2006_df = matriculados_2001_2013_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "2006"]]
matriculados_2007_df = matriculados_2001_2013_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "2007"]]
matriculados_2008_df = matriculados_2001_2013_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "2008"]]
matriculados_2009_df = matriculados_2001_2013_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "2009"]]
matriculados_2010_df = matriculados_2001_2013_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "2010"]]
matriculados_2011_df = matriculados_2001_2013_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "2011"]]
matriculados_2012_df = matriculados_2001_2013_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "2012"]]
matriculados_2013_df = matriculados_2001_2013_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "2013"]]

# %%
matriculados_2001_df["AÑO"] = [2001] * len(matriculados_2001_df.iloc[:, 0])
matriculados_2002_df["AÑO"] = [2002] * len(matriculados_2002_df.iloc[:, 0])
matriculados_2003_df["AÑO"] = [2003] * len(matriculados_2003_df.iloc[:, 0])
matriculados_2004_df["AÑO"] = [2004] * len(matriculados_2004_df.iloc[:, 0])
matriculados_2005_df["AÑO"] = [2005] * len(matriculados_2005_df.iloc[:, 0])
matriculados_2006_df["AÑO"] = [2006] * len(matriculados_2006_df.iloc[:, 0])
matriculados_2007_df["AÑO"] = [2007] * len(matriculados_2007_df.iloc[:, 0])
matriculados_2008_df["AÑO"] = [2008] * len(matriculados_2008_df.iloc[:, 0])
matriculados_2009_df["AÑO"] = [2009] * len(matriculados_2009_df.iloc[:, 0])
matriculados_2010_df["AÑO"] = [2010] * len(matriculados_2010_df.iloc[:, 0])
matriculados_2011_df["AÑO"] = [2011] * len(matriculados_2011_df.iloc[:, 0])
matriculados_2012_df["AÑO"] = [2012] * len(matriculados_2012_df.iloc[:, 0])
matriculados_2013_df["AÑO"] = [2013] * len(matriculados_2013_df.iloc[:, 0])

# %%
matriculados_2001_df.rename(columns={"2001":"MATRICULADOS"}, inplace = True)
matriculados_2002_df.rename(columns={"2002":"MATRICULADOS"}, inplace = True)
matriculados_2003_df.rename(columns={"2003":"MATRICULADOS"}, inplace = True)
matriculados_2004_df.rename(columns={"2004":"MATRICULADOS"}, inplace = True)
matriculados_2005_df.rename(columns={"2005":"MATRICULADOS"}, inplace = True)
matriculados_2006_df.rename(columns={"2006":"MATRICULADOS"}, inplace = True)
matriculados_2007_df.rename(columns={"2007":"MATRICULADOS"}, inplace = True)
matriculados_2008_df.rename(columns={"2008":"MATRICULADOS"}, inplace = True)
matriculados_2009_df.rename(columns={"2009":"MATRICULADOS"}, inplace = True)
matriculados_2010_df.rename(columns={"2010":"MATRICULADOS"}, inplace = True)
matriculados_2011_df.rename(columns={"2011":"MATRICULADOS"}, inplace = True)
matriculados_2012_df.rename(columns={"2012":"MATRICULADOS"}, inplace = True)
matriculados_2013_df.rename(columns={"2013":"MATRICULADOS"}, inplace = True)

# %%
matriculados_2001_df
matriculados_2002_df
matriculados_2003_df
matriculados_2004_df
matriculados_2005_df
matriculados_2006_df
matriculados_2007_df
matriculados_2008_df
matriculados_2009_df
matriculados_2010_df
matriculados_2011_df
matriculados_2012_df
matriculados_2013_df
# Out:
#                INSTITUCION DE EDUCACION SUPERIOR (IES)  ...   AÑO
# 0                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2013
# 1                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2013
# 2                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2013
# 3                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2013
# 4                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...  2013
# ..                                                 ...  ...   ...
# 748  CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA ATEC  ...  2013
# 749  CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA ATEC  ...  2013
# 750             CORPORACION ACADEMIA SUPERIOR DE ARTES  ...  2013
# 751               SERVICIO NACIONAL DE APRENDIZAJESENA  ...  2013
# 752               SERVICIO NACIONAL DE APRENDIZAJESENA  ...  2013
#
# [753 rows x 5 columns]

# %%
matriculados_2001_df = matriculados_2001_df.loc[matriculados_2001_df["MATRICULADOS"]!=0, :]
matriculados_2002_df = matriculados_2002_df.loc[matriculados_2002_df["MATRICULADOS"]!=0, :]
matriculados_2003_df = matriculados_2003_df.loc[matriculados_2003_df["MATRICULADOS"]!=0, :]
matriculados_2004_df = matriculados_2004_df.loc[matriculados_2004_df["MATRICULADOS"]!=0, :]
matriculados_2005_df = matriculados_2005_df.loc[matriculados_2005_df["MATRICULADOS"]!=0, :]
matriculados_2006_df = matriculados_2006_df.loc[matriculados_2006_df["MATRICULADOS"]!=0, :]
matriculados_2007_df = matriculados_2007_df.loc[matriculados_2007_df["MATRICULADOS"]!=0, :]
matriculados_2008_df = matriculados_2008_df.loc[matriculados_2008_df["MATRICULADOS"]!=0, :]
matriculados_2009_df = matriculados_2009_df.loc[matriculados_2009_df["MATRICULADOS"]!=0, :]
matriculados_2010_df = matriculados_2010_df.loc[matriculados_2010_df["MATRICULADOS"]!=0, :]
matriculados_2011_df = matriculados_2011_df.loc[matriculados_2011_df["MATRICULADOS"]!=0, :]
matriculados_2012_df = matriculados_2012_df.loc[matriculados_2012_df["MATRICULADOS"]!=0, :]
matriculados_2013_df = matriculados_2013_df.loc[matriculados_2013_df["MATRICULADOS"]!=0, :]

# %%
matriculados_2001_df = matriculados_2001_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "AÑO", "MATRICULADOS"]]
matriculados_2002_df = matriculados_2002_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "AÑO", "MATRICULADOS"]]
matriculados_2003_df = matriculados_2003_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "AÑO", "MATRICULADOS"]]
matriculados_2004_df = matriculados_2004_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "AÑO", "MATRICULADOS"]]
matriculados_2005_df = matriculados_2005_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "AÑO", "MATRICULADOS"]]
matriculados_2006_df = matriculados_2006_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "AÑO", "MATRICULADOS"]]
matriculados_2007_df = matriculados_2007_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "AÑO", "MATRICULADOS"]]
matriculados_2008_df = matriculados_2008_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "AÑO", "MATRICULADOS"]]
matriculados_2009_df = matriculados_2009_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "AÑO", "MATRICULADOS"]]
matriculados_2010_df = matriculados_2010_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "AÑO", "MATRICULADOS"]]
matriculados_2011_df = matriculados_2011_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "AÑO", "MATRICULADOS"]]
matriculados_2012_df = matriculados_2012_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "AÑO", "MATRICULADOS"]]
matriculados_2013_df = matriculados_2013_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "AÑO", "MATRICULADOS"]]

# %%
matriculados_2001_df
# matriculados_2002_df
# matriculados_2003_df
# matriculados_2004_df
# matriculados_2005_df
# matriculados_2006_df
# matriculados_2007_df
# matriculados_2008_df
# matriculados_2009_df
# matriculados_2010_df
# matriculados_2011_df
# matriculados_2012_df
# matriculados_2013_df
# Out:
#                INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...          451
# 1                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...          697
# 2                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...          272
# 3                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...         1783
# 4                     UNIVERSIDAD NACIONAL DE COLOMBIA  ...          386
# ..                                                 ...  ...          ...
# 741  CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA ATEC  ...          169
# 742  CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA ATEC  ...          506
# 743  CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA ATEC  ...           50
# 744  CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA ATEC  ...           24
# 750             CORPORACION ACADEMIA SUPERIOR DE ARTES  ...           26
#
# [205 rows x 5 columns]

# %%
matriculados_2014_df
# Out:
#                 INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...          132
# 1                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...          127
# 2                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...          159
# 3                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...          166
# 4                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...          107
# ...                                                 ...  ...          ...
# 1879  CORPORACION EDUCATIVA INSTITUTO TECNICO SUPERI...  ...            5
# 1880               FUNDACION UNIVERSITARIA BELLAS ARTES  ...           94
# 1881               FUNDACION UNIVERSITARIA BELLAS ARTES  ...          107
# 1882               FUNDACION UNIVERSITARIA BELLAS ARTES  ...          111
# 1883               FUNDACION UNIVERSITARIA BELLAS ARTES  ...          101
#
# [1884 rows x 5 columns]

# %%
matriculados_2015_df = matriculados_2015_df.loc[:, ["INSTITUCION DE EDUCACION SUPERIOR (IES)", "NIVEL DE FORMACION", "NUCLEO BASICO DEL CONOCIMIENTO (NBC)", "AÑO", "MATRICULADOS"]]
matriculados_2015_df
# Out:
#      INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0           UNIVERSIDAD NACIONAL DE COLOMBIA  ...          131
# 1           UNIVERSIDAD NACIONAL DE COLOMBIA  ...          141
# 2           UNIVERSIDAD NACIONAL DE COLOMBIA  ...          167
# 3           UNIVERSIDAD NACIONAL DE COLOMBIA  ...          168
# 4           UNIVERSIDAD NACIONAL DE COLOMBIA  ...           96
# ...                                      ...  ...          ...
# 1933  CORPORACION ACADEMIA SUPERIOR DE ARTES  ...            2
# 1934    FUNDACION UNIVERSITARIA BELLAS ARTES  ...          122
# 1935    FUNDACION UNIVERSITARIA BELLAS ARTES  ...          121
# 1936    FUNDACION UNIVERSITARIA BELLAS ARTES  ...          132
# 1937    FUNDACION UNIVERSITARIA BELLAS ARTES  ...          143
#
# [1938 rows x 5 columns]

# %%
matriculados_2016_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          159
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          166
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          132
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          145
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          208
# ...                                       ...  ...          ...
# 1788     FUNDACION UNIVERSITARIA BELLAS ARTES  ...            1
# 1789     FUNDACION UNIVERSITARIA BELLAS ARTES  ...            1
# 1790     FUNDACION UNIVERSITARIA BELLAS ARTES  ...            1
# 1791  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           16
# 1792  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           12
#
# [1793 rows x 5 columns]

# %%
matriculados_2017_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          179
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          181
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          140
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          140
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          202
# ...                                       ...  ...          ...
# 1663     FUNDACION UNIVERSITARIA BELLAS ARTES  ...           82
# 1664  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           16
# 1665  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           17
# 1666  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           29
# 1667  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           28
#
# [1668 rows x 5 columns]

# %%
matriculados_2018_df
# Out:
#       INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          188
# 1            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          183
# 2            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          146
# 3            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          158
# 4            UNIVERSIDAD NACIONAL DE COLOMBIA  ...          221
# ...                                       ...  ...          ...
# 1865     FUNDACION UNIVERSITARIA BELLAS ARTES  ...            1
# 1866  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           14
# 1867  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           18
# 1868  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           28
# 1869  CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           27
#
# [1870 rows x 5 columns]

# %%
matriculados_2019_df
# Out:
#                 INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...          196
# 1                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...          189
# 2                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...          156
# 3                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...          169
# 4                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...          236
# ...                                                 ...  ...          ...
# 1817            CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           20
# 1818  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...  ...          243
# 1819  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...  ...          432
# 1820  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...  ...           55
# 1821  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...  ...          102
#
# [1822 rows x 5 columns]

# %%
matriculados_ls = [
                matriculados_2001_df,
                matriculados_2002_df,
                matriculados_2003_df,
                matriculados_2004_df,
                matriculados_2005_df,
                matriculados_2006_df,
                matriculados_2007_df,
                matriculados_2008_df,
                matriculados_2009_df,
                matriculados_2010_df,
                matriculados_2011_df,
                matriculados_2012_df,
                matriculados_2013_df,
                matriculados_2014_df,
                matriculados_2015_df,
                matriculados_2016_df,
                matriculados_2017_df,
                matriculados_2018_df,
                matriculados_2019_df
]

# %%
matriculados_df = pd.concat(matriculados_ls, ignore_index=True)

# %%
matriculados_df.AÑO.value_counts()
# Out:
# 2015    1938
# 2014    1884
# 2018    1870
# 2019    1822
# 2016    1793
# 2017    1668
# 2013     487
# 2011     472
# 2012     449
# 2009     317
# 2010     298
# 2008     278
# 2003     274
# 2007     272
# 2005     267
# 2004     262
# 2006     254
# 2002     243
# 2001     205
# Name: AÑO, dtype: int64

# %%
matriculados_df
# Out:
#                  INSTITUCION DE EDUCACION SUPERIOR (IES)  ... MATRICULADOS
# 0                       UNIVERSIDAD NACIONAL DE COLOMBIA  ...          451
# 1                       UNIVERSIDAD NACIONAL DE COLOMBIA  ...          697
# 2                       UNIVERSIDAD NACIONAL DE COLOMBIA  ...          272
# 3                       UNIVERSIDAD NACIONAL DE COLOMBIA  ...         1783
# 4                       UNIVERSIDAD NACIONAL DE COLOMBIA  ...          386
# ...                                                  ...  ...          ...
# 15048            CORPORACION UNIVERSITARIA U DE COLOMBIA  ...           20
# 15049  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...  ...          243
# 15050  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...  ...          432
# 15051  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...  ...           55
# 15052  INSTITUCION UNIVERSITARIA DIGITAL DE ANTIOQUIA...  ...          102
#
# [15053 rows x 5 columns]

# %%
graduados_2001_2016
# Out:
#        INSTITUCION DE EDUCACION SUPERIOR (IES)  ... GRADUADOS
# 0             UNIVERSIDAD NACIONAL DE COLOMBIA  ...         8
# 1             UNIVERSIDAD NACIONAL DE COLOMBIA  ...        35
# 2             UNIVERSIDAD NACIONAL DE COLOMBIA  ...        19
# 3             UNIVERSIDAD NACIONAL DE COLOMBIA  ...        19
# 4             UNIVERSIDAD NACIONAL DE COLOMBIA  ...        16
# ...                                        ...  ...       ...
# 11385                  UNIVERSIDAD DE MEDELLIN  ...        17
# 11386                  UNIVERSIDAD DE MEDELLIN  ...         7
# 11387  INSTITUCION UNIVERSITARIA PASCUAL BRAVO  ...        16
# 11388  INSTITUCION UNIVERSITARIA PASCUAL BRAVO  ...        15
# 11389  INSTITUCION UNIVERSITARIA PASCUAL BRAVO  ...         1
#
# [11390 rows x 5 columns]

# %%
graduados_2018
# Out:
#      INSTITUCION DE EDUCACION SUPERIOR (IES)  ... GRADUADOS
# 0           UNIVERSIDAD NACIONAL DE COLOMBIA  ...         7
# 1           UNIVERSIDAD NACIONAL DE COLOMBIA  ...         6
# 2           UNIVERSIDAD NACIONAL DE COLOMBIA  ...        11
# 3           UNIVERSIDAD NACIONAL DE COLOMBIA  ...         4
# 4           UNIVERSIDAD NACIONAL DE COLOMBIA  ...         7
# ...                                      ...  ...       ...
# 1197  CORPORACION ACADEMIA SUPERIOR DE ARTES  ...         1
# 1198    FUNDACION UNIVERSITARIA BELLAS ARTES  ...        16
# 1199    FUNDACION UNIVERSITARIA BELLAS ARTES  ...        11
# 1200    FUNDACION UNIVERSITARIA BELLAS ARTES  ...        11
# 1201    FUNDACION UNIVERSITARIA BELLAS ARTES  ...         6
#
# [1202 rows x 5 columns]

# %%
graduados_2019
# Out:
#                INSTITUCION DE EDUCACION SUPERIOR (IES)  ... GRADUADOS
# 0         INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...         3
# 1         INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...        15
# 2         INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA  ...         6
# 3           CORPORACION UNIVERSITARIA ADVENTISTA  UNAC  ...         1
# 4                                    UNIVERSIDAD EAFIT  ...        22
# ...                                                ...  ...       ...
# 1231                           UNIVERSIDAD DE MEDELLIN  ...         7
# 1232                           UNIVERSIDAD DE MEDELLIN  ...         1
# 1233                   UNIVERSIDAD DE SAN BUENAVENTURA  ...         6
# 1234                   UNIVERSIDAD DE SAN BUENAVENTURA  ...         3
# 1235  FUNDACION UNIVERSITARIA AUTONOMA DE LAS AMERICAS  ...         4
#
# [1236 rows x 5 columns]

# %%
graduados_ls = [graduados_2001_2016, graduados_2018, graduados_2019]
graduados_df = pd.concat(graduados_ls, ignore_index=True)
graduados_df
# Out:
#                 INSTITUCION DE EDUCACION SUPERIOR (IES)  ... GRADUADOS
# 0                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...         8
# 1                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...        35
# 2                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...        19
# 3                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...        19
# 4                      UNIVERSIDAD NACIONAL DE COLOMBIA  ...        16
# ...                                                 ...  ...       ...
# 13823                           UNIVERSIDAD DE MEDELLIN  ...         7
# 13824                           UNIVERSIDAD DE MEDELLIN  ...         1
# 13825                   UNIVERSIDAD DE SAN BUENAVENTURA  ...         6
# 13826                   UNIVERSIDAD DE SAN BUENAVENTURA  ...         3
# 13827  FUNDACION UNIVERSITARIA AUTONOMA DE LAS AMERICAS  ...         4
#
# [13828 rows x 5 columns]

# %%
matriculados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"].unique()
# Out:
# array(['UNIVERSIDAD NACIONAL DE COLOMBIA', 'UNIVERSIDAD DE ANTIOQUIA',
#        'UNIVERSIDAD PONTIFICIA BOLIVARIANA', 'UNIVERSIDAD EAFIT',
#        'UNIVERSIDAD DE SAN BUENAVENTURA', 'UNIVERSIDAD DE MEDELLIN',
#        'UNIVERSIDAD AUTONOMA LATINOAMERICANAUNAULA',
#        'UNIVERSIDAD COOPERATIVA DE COLOMBIA',
#        'COLEGIO MAYOR DE ANTIOQUIA',
#        'POLITECNICO COLOMBIANO JAIME ISAZA CADAVID',
#        'FUNDACION UNIVERSITARIA LUIS AMIGO FUNLAM',
#        'FUNDACION UNIVERSITARIA MARIA CANO',
#        'FUNDACION UNIVERSITARIA AUTONOMA DE LAS AMERICAS',
#        'INSTITUCION UNIVERSITARIA SALAZAR Y HERRERA',
#        'ESCUELA DE INGENIERIA DE ANTIOQUIA',
#        'CORPORACION UNIVERSITARIA ADVENTISTA  UNAC',
#        'CORPORACION UNIVERSITARIA REMINGTON',
#        'INSTITUCION UNIVERSITARIA PASCUAL BRAVO',
#        'TECNOLOGICO DE ANTIOQUIA', 'INSTITUTO TECNOLOGICO METROPOLITANO',
#        'FUNDACION ESCUELA COLOMBIANA DE MERCADOTECNIA ESCOLME',
# ...

# %%
graduados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"].unique()
# Out:
# array(['UNIVERSIDAD NACIONAL DE COLOMBIA', 'UNIVERSIDAD DE ANTIOQUIA',
#        'UNIVERSIDAD PONTIFICIA BOLIVARIANA', 'UNIVERSIDAD EAFIT-',
#        'UNIVERSIDAD DE SAN BUENAVENTURA', 'UNIVERSIDAD DE MEDELLIN',
#        'UNIVERSIDAD AUTONOMA LATINOAMERICANA-UNAULA-',
#        'UNIVERSIDAD COOPERATIVA DE COLOMBIA',
#        'COLEGIO MAYOR DE ANTIOQUIA',
#        'POLITECNICO COLOMBIANO JAIME ISAZA CADAVID', 'UNIVERSIDAD CES',
#        'FUNDACION UNIVERSITARIA LUIS AMIGO FUNLAM',
#        'FUNDACION UNIVERSITARIA MARIA CANO',
#        'FUNDACION UNIVERSITARIA AUTONOMA DE LAS AMERICAS',
#        'INSTITUCION UNIVERSITARIA  SALAZAR Y HERRERA', 'UNIVERSIDAD EIA',
#        'CORPORACION UNIVERSITARIA ADVENTISTA - UNAC',
#        'CORPORACION UNIVERSITARIA REMINGTON',
#        'INSTITUCION UNIVERSITARIA PASCUAL BRAVO',
#        'TECNOLOGICO DE ANTIOQUIA', 'INSTITUTO TECNOLOGICO METROPOLITANO',
#        'FUNDACION ESCUELA COLOMBIANA DE MERCADOTECNIA -ESCOLME-',
# ...

# %%
matriculados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"].replace(to_replace=['CORPORACION UNIVERSITARIA ADVENTISTA  UNAC',
                                                                               'CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA ATEC',
                                                                               'ESCUELA DE TECNOLOGIAS DE ANTIOQUIA ETA',
                                                                               'UNIVERSIDAD EAFIT',
                                                                               'FUNDACION ESCUELA COLOMBIANA DE MERCADOTECNIA ESCOLME',
                                                                               'UNIVERSIDAD CATOLICA LUIS AMIGOFUNLAM',
                                                                               'UNIVERSIDAD AUTONOMA LATINOAMERICANAUNAULA',
                                                                               'CENTRO EDUCACIONAL DE COMPUTOS Y SISTEMASCEDESISTEMAS', 
                                                                               'SERVICIO NACIONAL DE APRENDIZAJESENA'], 
                                                                   value=['CORPORACION UNIVERSITARIA ADVENTISTA - UNAC', 
                                                                          'CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA -ATEC-',
                                                                          'ESCUELA DE TECNOLOGIAS DE ANTIOQUIA -ETA-',
                                                                          'UNIVERSIDAD EAFIT-',
                                                                          'FUNDACION ESCUELA COLOMBIANA DE MERCADOTECNIA -ESCOLME-',
                                                                          'UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM',
                                                                          'UNIVERSIDAD AUTONOMA LATINOAMERICANA-UNAULA-',
                                                                          'CENTRO EDUCACIONAL DE COMPUTOS Y SISTEMAS-CEDESISTEMAS-',
                                                                          'SERVICIO NACIONAL DE APRENDIZAJE-SENA-'], inplace=True)

# %%
gradu_ies_set = set(graduados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"].unique())

# %%
matri_ies_set = set(matriculados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"].unique())

# %%
ies_ls = list(gradu_ies_set - matri_ies_set)

# %%
ies_ls
# Out:
# ['UNIVERSIDAD CATOLICA LUIS AMIGOFUNLAM',
#  'CORPORACION UNIVERSITARIA ADVENTISTA  UNAC',
#  'UNIVERSIDAD AUTONOMA LATINOAMERICANAUNAULA',
#  'CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA ATEC',
#  'FUNDACION ESCUELA COLOMBIANA DE MERCADOTECNIA ESCOLME',
#  'UNIVERSIDAD EAFIT']

# %%
to_replace_ls = ['CORPORACION UNIVERSITARIA ADVENTISTA - UNAC', 
                 'FUNDACION ESCUELA COLOMBIANA DE MERCADOTECNIA -ESCOLME-', 
                 'CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA -ATEC-',
                 'UNIVERSIDAD EAFIT-',
                 'UNIVERSIDAD AUTONOMA LATINOAMERICANA-UNAULA-',
                 'UNIVERSIDAD CATÓLICA LUIS AMIGÓ-FUNLAM']

# %%
graduados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"].replace(to_replace=ies_ls, value=to_replace_ls, inplace=True)

# %%
set(graduados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"].unique()) - set(matriculados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"].unique())
# Out:
# set()

# %%
matriculados_df["INSTITUCION DE EDUCACION SUPERIOR (IES)"].unique()
# Out:
# array(['UNIVERSIDAD NACIONAL DE COLOMBIA', 'UNIVERSIDAD DE ANTIOQUIA',
#        'UNIVERSIDAD PONTIFICIA BOLIVARIANA', 'UNIVERSIDAD EAFIT-',
#        'UNIVERSIDAD DE SAN BUENAVENTURA', 'UNIVERSIDAD DE MEDELLIN',
#        'UNIVERSIDAD AUTONOMA LATINOAMERICANA-UNAULA-',
#        'UNIVERSIDAD COOPERATIVA DE COLOMBIA',
#        'COLEGIO MAYOR DE ANTIOQUIA',
#        'POLITECNICO COLOMBIANO JAIME ISAZA CADAVID',
#        'FUNDACION UNIVERSITARIA LUIS AMIGO FUNLAM',
#        'FUNDACION UNIVERSITARIA MARIA CANO',
#        'FUNDACION UNIVERSITARIA AUTONOMA DE LAS AMERICAS',
#        'INSTITUCION UNIVERSITARIA SALAZAR Y HERRERA',
#        'ESCUELA DE INGENIERIA DE ANTIOQUIA',
#        'CORPORACION UNIVERSITARIA ADVENTISTA - UNAC',
#        'CORPORACION UNIVERSITARIA REMINGTON',
#        'INSTITUCION UNIVERSITARIA PASCUAL BRAVO',
#        'TECNOLOGICO DE ANTIOQUIA', 'INSTITUTO TECNOLOGICO METROPOLITANO',
#        'FUNDACION ESCUELA COLOMBIANA DE MERCADOTECNIA -ESCOLME-',
# ...

# %%
matriculados_df["NIVEL DE FORMACION"].replace(to_replace="TECNICA PROFESIONAL", value="FORMACION TECNICA PROFESIONAL", inplace=True)

# %%
matriculados_df["NIVEL DE FORMACION"].value_counts()
# Out:
# UNIVERSITARIA                    6570
# TECNOLOGICA                      2968
# MAESTRIA                         2064
# ESPECIALIZACION                  1320
# ESPECIALIZACION UNIVERSITARIA     977
# DOCTORADO                         915
# FORMACION TECNICA PROFESIONAL     239
# Name: NIVEL DE FORMACION, dtype: int64

# %%
for fila in range(0, len(matriculados_df["NIVEL DE FORMACION"]):
  if matriculados_df.iloc[fila, 1] == "TECNICA PROFESIONAL":

# %%
matriculados_df.to_csv("/content/matriculados_2001_2019.csv", index=False)
# graduados_df.to_csv("/content/graduados_2001_2019.csv", index=False)

# %% [markdown]
# *   ¿Cuál es el número de estudiantes y graduados por IES por año?

# %%
matriculados_ies_df = pd.DataFrame(matriculados_df.groupby(["INSTITUCION DE EDUCACION SUPERIOR (IES)", "AÑO"]).MATRICULADOS.sum()).unstack(fill_value=0)
matriculados_ies_df = matriculados_ies_df.stack()
matriculados_ies_df.index
# Out:
#                                                          MATRICULADOS
# INSTITUCION DE EDUCACION SUPERIOR (IES)            AÑO
# CENTRO EDUCACIONAL DE COMPUTOS Y SISTEMAS-CEDES... 2001           370
#                                                    2002           325
#                                                    2003           328
#                                                    2004           308
#                                                    2005           280
# ...                                                               ...
# UNIVERSIDAD PONTIFICIA BOLIVARIANA                 2015          8166
#                                                    2016          8243
#                                                    2017          8705
#                                                    2018          9585
#                                                    2019          6941
#
# [684 rows x 1 columns]

# %%
graduados_ies_df = pd.DataFrame(graduados_df.groupby(["INSTITUCION DE EDUCACION SUPERIOR (IES)", "AÑO"], ).GRADUADOS.sum()).unstack(fill_value=0)
graduados_ies_df = graduados_ies_df.stack()
graduados_ies_df
# Out:
#                                                          GRADUADOS
# INSTITUCION DE EDUCACION SUPERIOR (IES)            AÑO
# CENTRO EDUCACIONAL DE COMPUTOS Y SISTEMAS-CEDES... 2001         19
#                                                    2002         31
#                                                    2003          5
#                                                    2004          2
#                                                    2005          0
# ...                                                            ...
# UNIVERSIDAD PONTIFICIA BOLIVARIANA                 2014        536
#                                                    2015        558
#                                                    2016        620
#                                                    2018        923
#                                                    2019        844
#
# [558 rows x 1 columns]

# %%
set(matriculados_ies_df.index) - set(graduados_ies_df.index)
# Out:
# {('CENTRO EDUCACIONAL DE COMPUTOS Y SISTEMAS-CEDESISTEMAS-', 2017),
#  ('COLEGIO MAYOR DE ANTIOQUIA', 2017),
#  ('CORPORACION ACADEMIA SUPERIOR DE ARTES', 2017),
#  ('CORPORACION ACADEMIA TECNOLOGICA DE COLOMBIA -ATEC-', 2017),
#  ('CORPORACION COLEGIATURA COLOMBIANA', 2017),
#  ('CORPORACION EDUCATIVA INSTITUTO TECNICO SUPERIOR DE ARTES IDEARTES', 2001),
#  ('CORPORACION EDUCATIVA INSTITUTO TECNICO SUPERIOR DE ARTES IDEARTES', 2002),
#  ('CORPORACION EDUCATIVA INSTITUTO TECNICO SUPERIOR DE ARTES IDEARTES', 2003),
#  ('CORPORACION EDUCATIVA INSTITUTO TECNICO SUPERIOR DE ARTES IDEARTES', 2004),
#  ('CORPORACION EDUCATIVA INSTITUTO TECNICO SUPERIOR DE ARTES IDEARTES', 2005),
#  ('CORPORACION EDUCATIVA INSTITUTO TECNICO SUPERIOR DE ARTES IDEARTES', 2006),
#  ('CORPORACION EDUCATIVA INSTITUTO TECNICO SUPERIOR DE ARTES IDEARTES', 2007),
#  ('CORPORACION EDUCATIVA INSTITUTO TECNICO SUPERIOR DE ARTES IDEARTES', 2008),
# ...

# %% [markdown]
# *   ¿Cuál es el número de estudiantes y graduados por nivel de formación por año?

# %% [markdown]
# *   ¿Cuál es el número de estudiantes y graduados por Núcleo Básico del Conocimiento (NBC) por año?
